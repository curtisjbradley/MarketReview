# %%
import pandas as pd
from fastparquet import ParquetFile
import duckdb
import re

from datetime import datetime, timedelta

# %%
stkr=  ParquetFile("../sticker.parquet").to_pandas()

# %%
target = 'type'

# %%
pvt = stkr.pivot(values='volume', index='item', columns = 'date').reset_index()

# %%
items = duckdb.query('select * from pvt join (select distinct type, item from stkr) as t2 on t2.item = pvt.item').df()

# %%
cols = list(items.columns[-1000:-20])
cols
# Out:
# ['2025-02-15 01:00:00',
#  '2025-02-16 01:00:00',
#  '2025-02-17 01:00:00',
#  '2025-02-18 01:00:00',
#  '2025-02-19 01:00:00',
#  '2025-02-20 01:00:00',
#  '2025-02-21 01:00:00',
#  '2025-02-22 01:00:00',
#  '2025-02-23 01:00:00',
#  '2025-02-24 01:00:00',
#  '2025-02-25 01:00:00',
#  '2025-02-26 01:00:00',
#  '2025-02-27 01:00:00',
#  '2025-02-28 01:00:00',
#  '2025-03-01 01:00:00',
#  '2025-03-02 01:00:00',
#  '2025-03-03 01:00:00',
#  '2025-03-04 01:00:00',
#  '2025-03-05 01:00:00',
#  '2025-03-06 01:00:00',
#  '2025-03-07 01:00:00',
#  '2025-03-08 01:00:00',
#  '2025-03-09 01:00:00',
#  '2025-03-10 01:00:00',
#  '2025-03-11 01:00:00',
#  '2025-03-12 01:00:00',
#  '2025-03-13 01:00:00',
#  '2025-03-14 01:00:00',
#  '2025-03-15 01:00:00',
#  '2025-03-16 01:00:00',
#  '2025-03-17 01:00:00',
#  '2025-03-18 01:00:00',
#  '2025-03-19 01:00:00',
#  '2025-03-20 01:00:00',
#  '2025-03-21 01:00:00',
#  '2025-03-22 01:00:00',
#  '2025-03-23 01:00:00',
#  '2025-03-24 01:00:00',
#  '2025-03-25 01:00:00',
#  '2025-03-26 01:00:00',
#  '2025-03-27 01:00:00',
#  '2025-03-28 01:00:00',
#  '2025-03-29 01:00:00',
#  '2025-03-30 01:00:00',
#  '2025-03-31 01:00:00',
#  '2025-04-01 01:00:00',
#  '2025-04-02 01:00:00',
#  '2025-04-03 01:00:00',
#  '2025-04-04 01:00:00',
#  '2025-04-05 01:00:00',
#  '2025-04-06 01:00:00',
#  '2025-04-07 01:00:00',
#  '2025-04-08 01:00:00',
#  '2025-04-09 01:00:00',
#  '2025-04-10 01:00:00',
#  '2025-04-11 01:00:00',
#  '2025-04-12 01:00:00',
#  '2025-04-13 01:00:00',
#  '2025-04-14 01:00:00',
#  '2025-04-15 01:00:00',
#  '2025-04-16 01:00:00',
#  '2025-04-17 01:00:00',
#  '2025-04-18 01:00:00',
#  '2025-04-19 01:00:00',
#  '2025-04-20 01:00:00',
#  '2025-04-21 01:00:00',
#  '2025-04-22 01:00:00',
#  '2025-04-23 01:00:00',
#  '2025-04-24 01:00:00',
#  '2025-04-25 01:00:00',
#  '2025-04-26 01:00:00',
#  '2025-04-27 01:00:00',
#  '2025-04-28 01:00:00',
#  '2025-04-29 01:00:00',
#  '2025-04-30 01:00:00',
#  '2025-05-01 01:00:00',
#  '2025-05-02 01:00:00',
#  '2025-05-03 01:00:00',
#  '2025-05-04 01:00:00',
#  '2025-05-05 01:00:00',
#  '2025-05-06 01:00:00',
#  '2025-05-07 01:00:00',
#  '2025-05-08 01:00:00',
#  '2025-05-09 01:00:00',
#  '2025-05-10 01:00:00',
#  '2025-05-11 01:00:00',
#  '2025-05-12 01:00:00',
#  '2025-05-13 01:00:00',
#  '2025-05-14 01:00:00',
#  '2025-05-15 01:00:00',
#  '2025-05-16 01:00:00',
#  '2025-05-17 01:00:00',
#  '2025-05-18 01:00:00',
#  '2025-05-19 01:00:00',
#  '2025-05-20 01:00:00',
#  '2025-05-21 01:00:00',
#  '2025-05-22 01:00:00',
#  '2025-05-23 01:00:00',
#  '2025-05-24 01:00:00',
#  '2025-05-25 01:00:00',
#  '2025-05-26 01:00:00',
#  '2025-05-27 01:00:00',
#  '2025-05-28 01:00:00',
#  '2025-05-29 01:00:00',
#  '2025-05-30 01:00:00',
#  '2025-05-31 01:00:00',
#  '2025-06-01 01:00:00',
#  '2025-06-02 01:00:00',
#  '2025-06-03 01:00:00',
#  '2025-06-04 01:00:00',
#  '2025-06-05 01:00:00',
#  '2025-06-06 01:00:00',
#  '2025-06-07 01:00:00',
#  '2025-06-08 01:00:00',
#  '2025-06-09 01:00:00',
#  '2025-06-10 01:00:00',
#  '2025-06-11 01:00:00',
#  '2025-06-12 01:00:00',
#  '2025-06-13 01:00:00',
#  '2025-06-14 01:00:00',
#  '2025-06-15 01:00:00',
#  '2025-06-16 01:00:00',
#  '2025-06-17 01:00:00',
#  '2025-06-18 01:00:00',
#  '2025-06-19 01:00:00',
#  '2025-06-20 01:00:00',
#  '2025-06-21 01:00:00',
#  '2025-06-22 01:00:00',
#  '2025-06-23 01:00:00',
#  '2025-06-24 01:00:00',
#  '2025-06-25 01:00:00',
#  '2025-06-26 01:00:00',
#  '2025-06-27 01:00:00',
#  '2025-06-28 01:00:00',
#  '2025-06-29 01:00:00',
#  '2025-06-30 01:00:00',
#  '2025-07-01 01:00:00',
#  '2025-07-02 01:00:00',
#  '2025-07-03 01:00:00',
#  '2025-07-04 01:00:00',
#  '2025-07-05 01:00:00',
#  '2025-07-06 01:00:00',
#  '2025-07-07 01:00:00',
#  '2025-07-08 01:00:00',
#  '2025-07-09 01:00:00',
#  '2025-07-10 01:00:00',
#  '2025-07-11 01:00:00',
#  '2025-07-12 01:00:00',
#  '2025-07-13 01:00:00',
#  '2025-07-14 01:00:00',
#  '2025-07-15 01:00:00',
#  '2025-07-16 01:00:00',
#  '2025-07-17 01:00:00',
#  '2025-07-18 01:00:00',
#  '2025-07-19 01:00:00',
#  '2025-07-20 01:00:00',
#  '2025-07-21 01:00:00',
#  '2025-07-22 01:00:00',
#  '2025-07-23 01:00:00',
#  '2025-07-24 01:00:00',
#  '2025-07-25 01:00:00',
#  '2025-07-26 01:00:00',
#  '2025-07-27 01:00:00',
#  '2025-07-28 01:00:00',
#  '2025-07-29 01:00:00',
#  '2025-07-30 01:00:00',
#  '2025-07-31 01:00:00',
#  '2025-08-01 01:00:00',
#  '2025-08-02 01:00:00',
#  '2025-08-03 01:00:00',
#  '2025-08-04 01:00:00',
#  '2025-08-05 01:00:00',
#  '2025-08-06 01:00:00',
#  '2025-08-07 01:00:00',
#  '2025-08-08 01:00:00',
#  '2025-08-09 01:00:00',
#  '2025-08-10 01:00:00',
#  '2025-08-11 01:00:00',
#  '2025-08-12 01:00:00',
#  '2025-08-13 01:00:00',
#  '2025-08-14 01:00:00',
#  '2025-08-15 01:00:00',
#  '2025-08-16 01:00:00',
#  '2025-08-17 01:00:00',
#  '2025-08-18 01:00:00',
#  '2025-08-19 01:00:00',
#  '2025-08-20 01:00:00',
#  '2025-08-21 01:00:00',
#  '2025-08-22 01:00:00',
#  '2025-08-23 01:00:00',
#  '2025-08-24 01:00:00',
#  '2025-08-25 01:00:00',
#  '2025-08-26 01:00:00',
#  '2025-08-27 01:00:00',
#  '2025-08-28 01:00:00',
#  '2025-08-29 01:00:00',
#  '2025-08-30 01:00:00',
#  '2025-08-31 01:00:00',
#  '2025-09-01 01:00:00',
#  '2025-09-02 01:00:00',
#  '2025-09-03 01:00:00',
#  '2025-09-04 01:00:00',
#  '2025-09-05 01:00:00',
#  '2025-09-06 01:00:00',
#  '2025-09-07 01:00:00',
#  '2025-09-08 01:00:00',
#  '2025-09-09 01:00:00',
#  '2025-09-10 01:00:00',
#  '2025-09-11 01:00:00',
#  '2025-09-12 01:00:00',
#  '2025-09-13 01:00:00',
#  '2025-09-14 01:00:00',
#  '2025-09-15 01:00:00',
#  '2025-09-16 01:00:00',
#  '2025-09-17 01:00:00',
#  '2025-09-18 01:00:00',
#  '2025-09-19 01:00:00',
#  '2025-09-20 01:00:00',
#  '2025-09-21 01:00:00',
#  '2025-09-22 01:00:00',
#  '2025-09-23 01:00:00',
#  '2025-09-24 01:00:00',
#  '2025-09-25 01:00:00',
#  '2025-09-26 01:00:00',
#  '2025-09-27 01:00:00',
#  '2025-09-28 01:00:00',
#  '2025-09-29 01:00:00',
#  '2025-09-30 01:00:00',
#  '2025-10-01 01:00:00',
#  '2025-10-02 01:00:00',
#  '2025-10-03 01:00:00',
#  '2025-10-04 01:00:00',
#  '2025-10-05 01:00:00',
#  '2025-10-06 01:00:00',
#  '2025-10-07 01:00:00',
#  '2025-10-08 01:00:00',
#  '2025-10-09 01:00:00',
#  '2025-10-10 01:00:00',
#  '2025-10-11 01:00:00',
#  '2025-10-11 19:00:00',
#  '2025-10-11 20:00:00',
#  '2025-10-11 21:00:00',
#  '2025-10-11 22:00:00',
#  '2025-10-11 23:00:00',
#  '2025-10-12 00:00:00',
#  '2025-10-12 01:00:00',
#  '2025-10-12 02:00:00',
#  '2025-10-12 03:00:00',
#  '2025-10-12 04:00:00',
#  '2025-10-12 05:00:00',
#  '2025-10-12 06:00:00',
#  '2025-10-12 07:00:00',
#  '2025-10-12 08:00:00',
#  '2025-10-12 09:00:00',
#  '2025-10-12 10:00:00',
#  '2025-10-12 11:00:00',
#  '2025-10-12 12:00:00',
#  '2025-10-12 13:00:00',
#  '2025-10-12 14:00:00',
#  '2025-10-12 15:00:00',
#  '2025-10-12 16:00:00',
#  '2025-10-12 17:00:00',
#  '2025-10-12 18:00:00',
#  '2025-10-12 19:00:00',
#  '2025-10-12 20:00:00',
#  '2025-10-12 21:00:00',
#  '2025-10-12 22:00:00',
#  '2025-10-12 23:00:00',
#  '2025-10-13 00:00:00',
#  '2025-10-13 01:00:00',
#  '2025-10-13 02:00:00',
#  '2025-10-13 03:00:00',
#  '2025-10-13 04:00:00',
#  '2025-10-13 05:00:00',
#  '2025-10-13 06:00:00',
#  '2025-10-13 07:00:00',
#  '2025-10-13 08:00:00',
#  '2025-10-13 09:00:00',
#  '2025-10-13 10:00:00',
#  '2025-10-13 11:00:00',
#  '2025-10-13 12:00:00',
#  '2025-10-13 13:00:00',
#  '2025-10-13 14:00:00',
#  '2025-10-13 15:00:00',
#  '2025-10-13 16:00:00',
#  '2025-10-13 17:00:00',
#  '2025-10-13 18:00:00',
#  '2025-10-13 19:00:00',
#  '2025-10-13 20:00:00',
#  '2025-10-13 21:00:00',
#  '2025-10-13 22:00:00',
#  '2025-10-13 23:00:00',
#  '2025-10-14 00:00:00',
#  '2025-10-14 01:00:00',
#  '2025-10-14 02:00:00',
#  '2025-10-14 03:00:00',
#  '2025-10-14 04:00:00',
#  '2025-10-14 05:00:00',
#  '2025-10-14 06:00:00',
#  '2025-10-14 07:00:00',
#  '2025-10-14 08:00:00',
#  '2025-10-14 09:00:00',
#  '2025-10-14 10:00:00',
#  '2025-10-14 11:00:00',
#  '2025-10-14 12:00:00',
#  '2025-10-14 13:00:00',
#  '2025-10-14 14:00:00',
#  '2025-10-14 15:00:00',
#  '2025-10-14 16:00:00',
#  '2025-10-14 17:00:00',
#  '2025-10-14 18:00:00',
#  '2025-10-14 19:00:00',
#  '2025-10-14 20:00:00',
#  '2025-10-14 21:00:00',
#  '2025-10-14 22:00:00',
#  '2025-10-14 23:00:00',
#  '2025-10-15 00:00:00',
#  '2025-10-15 01:00:00',
#  '2025-10-15 02:00:00',
#  '2025-10-15 03:00:00',
#  '2025-10-15 04:00:00',
#  '2025-10-15 05:00:00',
#  '2025-10-15 06:00:00',
#  '2025-10-15 07:00:00',
#  '2025-10-15 08:00:00',
#  '2025-10-15 09:00:00',
#  '2025-10-15 10:00:00',
#  '2025-10-15 11:00:00',
#  '2025-10-15 12:00:00',
#  '2025-10-15 13:00:00',
#  '2025-10-15 14:00:00',
#  '2025-10-15 15:00:00',
#  '2025-10-15 16:00:00',
#  '2025-10-15 17:00:00',
#  '2025-10-15 18:00:00',
#  '2025-10-15 19:00:00',
#  '2025-10-15 20:00:00',
#  '2025-10-15 21:00:00',
#  '2025-10-15 22:00:00',
#  '2025-10-15 23:00:00',
#  '2025-10-16 00:00:00',
#  '2025-10-16 01:00:00',
#  '2025-10-16 02:00:00',
#  '2025-10-16 03:00:00',
#  '2025-10-16 04:00:00',
#  '2025-10-16 05:00:00',
#  '2025-10-16 06:00:00',
#  '2025-10-16 07:00:00',
#  '2025-10-16 08:00:00',
#  '2025-10-16 09:00:00',
#  '2025-10-16 10:00:00',
#  '2025-10-16 11:00:00',
#  '2025-10-16 12:00:00',
#  '2025-10-16 13:00:00',
#  '2025-10-16 14:00:00',
#  '2025-10-16 15:00:00',
#  '2025-10-16 16:00:00',
#  '2025-10-16 17:00:00',
#  '2025-10-16 18:00:00',
#  '2025-10-16 19:00:00',
#  '2025-10-16 20:00:00',
#  '2025-10-16 21:00:00',
#  '2025-10-16 22:00:00',
#  '2025-10-16 23:00:00',
#  '2025-10-17 00:00:00',
#  '2025-10-17 01:00:00',
#  '2025-10-17 02:00:00',
#  '2025-10-17 03:00:00',
#  '2025-10-17 04:00:00',
#  '2025-10-17 05:00:00',
#  '2025-10-17 06:00:00',
#  '2025-10-17 07:00:00',
#  '2025-10-17 08:00:00',
#  '2025-10-17 09:00:00',
#  '2025-10-17 10:00:00',
#  '2025-10-17 11:00:00',
#  '2025-10-17 12:00:00',
#  '2025-10-17 13:00:00',
#  '2025-10-17 14:00:00',
#  '2025-10-17 15:00:00',
#  '2025-10-17 16:00:00',
#  '2025-10-17 17:00:00',
#  '2025-10-17 18:00:00',
#  '2025-10-17 19:00:00',
#  '2025-10-17 20:00:00',
#  '2025-10-17 21:00:00',
#  '2025-10-17 22:00:00',
#  '2025-10-17 23:00:00',
#  '2025-10-18 00:00:00',
#  '2025-10-18 01:00:00',
#  '2025-10-18 02:00:00',
#  '2025-10-18 03:00:00',
#  '2025-10-18 04:00:00',
#  '2025-10-18 05:00:00',
#  '2025-10-18 06:00:00',
#  '2025-10-18 07:00:00',
#  '2025-10-18 08:00:00',
#  '2025-10-18 09:00:00',
#  '2025-10-18 10:00:00',
#  '2025-10-18 11:00:00',
#  '2025-10-18 12:00:00',
#  '2025-10-18 13:00:00',
#  '2025-10-18 14:00:00',
#  '2025-10-18 15:00:00',
#  '2025-10-18 16:00:00',
#  '2025-10-18 17:00:00',
#  '2025-10-18 18:00:00',
#  '2025-10-18 19:00:00',
#  '2025-10-18 20:00:00',
#  '2025-10-18 21:00:00',
#  '2025-10-18 22:00:00',
#  '2025-10-18 23:00:00',
#  '2025-10-19 00:00:00',
#  '2025-10-19 01:00:00',
#  '2025-10-19 02:00:00',
#  '2025-10-19 03:00:00',
#  '2025-10-19 04:00:00',
#  '2025-10-19 05:00:00',
#  '2025-10-19 06:00:00',
#  '2025-10-19 07:00:00',
#  '2025-10-19 08:00:00',
#  '2025-10-19 09:00:00',
#  '2025-10-19 10:00:00',
#  '2025-10-19 11:00:00',
#  '2025-10-19 12:00:00',
#  '2025-10-19 13:00:00',
#  '2025-10-19 14:00:00',
#  '2025-10-19 15:00:00',
#  '2025-10-19 16:00:00',
#  '2025-10-19 17:00:00',
#  '2025-10-19 18:00:00',
#  '2025-10-19 19:00:00',
#  '2025-10-19 20:00:00',
#  '2025-10-19 21:00:00',
#  '2025-10-19 22:00:00',
#  '2025-10-19 23:00:00',
#  '2025-10-20 00:00:00',
#  '2025-10-20 01:00:00',
#  '2025-10-20 02:00:00',
#  '2025-10-20 03:00:00',
#  '2025-10-20 04:00:00',
#  '2025-10-20 05:00:00',
#  '2025-10-20 06:00:00',
#  '2025-10-20 07:00:00',
#  '2025-10-20 08:00:00',
#  '2025-10-20 09:00:00',
#  '2025-10-20 10:00:00',
#  '2025-10-20 11:00:00',
#  '2025-10-20 12:00:00',
#  '2025-10-20 13:00:00',
#  '2025-10-20 14:00:00',
#  '2025-10-20 15:00:00',
#  '2025-10-20 16:00:00',
#  '2025-10-20 17:00:00',
#  '2025-10-20 18:00:00',
#  '2025-10-20 19:00:00',
#  '2025-10-20 20:00:00',
#  '2025-10-20 21:00:00',
#  '2025-10-20 22:00:00',
#  '2025-10-20 23:00:00',
#  '2025-10-21 00:00:00',
#  '2025-10-21 01:00:00',
#  '2025-10-21 02:00:00',
#  '2025-10-21 03:00:00',
#  '2025-10-21 04:00:00',
#  '2025-10-21 05:00:00',
#  '2025-10-21 06:00:00',
#  '2025-10-21 07:00:00',
#  '2025-10-21 08:00:00',
#  '2025-10-21 09:00:00',
#  '2025-10-21 10:00:00',
#  '2025-10-21 11:00:00',
#  '2025-10-21 12:00:00',
#  '2025-10-21 13:00:00',
#  '2025-10-21 14:00:00',
#  '2025-10-21 15:00:00',
#  '2025-10-21 16:00:00',
#  '2025-10-21 17:00:00',
#  '2025-10-21 18:00:00',
#  '2025-10-21 19:00:00',
#  '2025-10-21 20:00:00',
#  '2025-10-21 21:00:00',
#  '2025-10-21 22:00:00',
#  '2025-10-21 23:00:00',
#  '2025-10-22 00:00:00',
#  '2025-10-22 01:00:00',
#  '2025-10-22 02:00:00',
#  '2025-10-22 03:00:00',
#  '2025-10-22 04:00:00',
#  '2025-10-22 05:00:00',
#  '2025-10-22 06:00:00',
#  '2025-10-22 07:00:00',
#  '2025-10-22 08:00:00',
#  '2025-10-22 09:00:00',
#  '2025-10-22 10:00:00',
#  '2025-10-22 11:00:00',
#  '2025-10-22 12:00:00',
#  '2025-10-22 13:00:00',
#  '2025-10-22 14:00:00',
#  '2025-10-22 15:00:00',
#  '2025-10-22 16:00:00',
#  '2025-10-22 17:00:00',
#  '2025-10-22 18:00:00',
#  '2025-10-22 19:00:00',
#  '2025-10-22 20:00:00',
#  '2025-10-22 21:00:00',
#  '2025-10-22 22:00:00',
#  '2025-10-22 23:00:00',
#  '2025-10-23 00:00:00',
#  '2025-10-23 01:00:00',
#  '2025-10-23 02:00:00',
#  '2025-10-23 03:00:00',
#  '2025-10-23 04:00:00',
#  '2025-10-23 05:00:00',
#  '2025-10-23 06:00:00',
#  '2025-10-23 07:00:00',
#  '2025-10-23 08:00:00',
#  '2025-10-23 09:00:00',
#  '2025-10-23 10:00:00',
#  '2025-10-23 11:00:00',
#  '2025-10-23 12:00:00',
#  '2025-10-23 13:00:00',
#  '2025-10-23 14:00:00',
#  '2025-10-23 15:00:00',
#  '2025-10-23 16:00:00',
#  '2025-10-23 17:00:00',
#  '2025-10-23 18:00:00',
#  '2025-10-23 19:00:00',
#  '2025-10-23 20:00:00',
#  '2025-10-23 21:00:00',
#  '2025-10-23 22:00:00',
#  '2025-10-23 23:00:00',
#  '2025-10-24 00:00:00',
#  '2025-10-24 01:00:00',
#  '2025-10-24 02:00:00',
#  '2025-10-24 03:00:00',
#  '2025-10-24 04:00:00',
#  '2025-10-24 05:00:00',
#  '2025-10-24 06:00:00',
#  '2025-10-24 07:00:00',
#  '2025-10-24 08:00:00',
#  '2025-10-24 09:00:00',
#  '2025-10-24 10:00:00',
#  '2025-10-24 11:00:00',
#  '2025-10-24 12:00:00',
#  '2025-10-24 13:00:00',
#  '2025-10-24 14:00:00',
#  '2025-10-24 15:00:00',
#  '2025-10-24 16:00:00',
#  '2025-10-24 17:00:00',
#  '2025-10-24 18:00:00',
#  '2025-10-24 19:00:00',
#  '2025-10-24 20:00:00',
#  '2025-10-24 21:00:00',
#  '2025-10-24 22:00:00',
#  '2025-10-24 23:00:00',
#  '2025-10-25 00:00:00',
#  '2025-10-25 01:00:00',
#  '2025-10-25 02:00:00',
#  '2025-10-25 03:00:00',
#  '2025-10-25 04:00:00',
#  '2025-10-25 05:00:00',
#  '2025-10-25 06:00:00',
#  '2025-10-25 07:00:00',
#  '2025-10-25 08:00:00',
#  '2025-10-25 09:00:00',
#  '2025-10-25 10:00:00',
#  '2025-10-25 11:00:00',
#  '2025-10-25 12:00:00',
#  '2025-10-25 13:00:00',
#  '2025-10-25 14:00:00',
#  '2025-10-25 15:00:00',
#  '2025-10-25 16:00:00',
#  '2025-10-25 17:00:00',
#  '2025-10-25 18:00:00',
#  '2025-10-25 19:00:00',
#  '2025-10-25 20:00:00',
#  '2025-10-25 21:00:00',
#  '2025-10-25 22:00:00',
#  '2025-10-25 23:00:00',
#  '2025-10-26 00:00:00',
#  '2025-10-26 01:00:00',
#  '2025-10-26 02:00:00',
#  '2025-10-26 03:00:00',
#  '2025-10-26 04:00:00',
#  '2025-10-26 05:00:00',
#  '2025-10-26 06:00:00',
#  '2025-10-26 07:00:00',
#  '2025-10-26 08:00:00',
#  '2025-10-26 09:00:00',
#  '2025-10-26 10:00:00',
#  '2025-10-26 11:00:00',
#  '2025-10-26 12:00:00',
#  '2025-10-26 13:00:00',
#  '2025-10-26 14:00:00',
#  '2025-10-26 15:00:00',
#  '2025-10-26 16:00:00',
#  '2025-10-26 17:00:00',
#  '2025-10-26 18:00:00',
#  '2025-10-26 19:00:00',
#  '2025-10-26 20:00:00',
#  '2025-10-26 21:00:00',
#  '2025-10-26 22:00:00',
#  '2025-10-26 23:00:00',
#  '2025-10-27 00:00:00',
#  '2025-10-27 01:00:00',
#  '2025-10-27 02:00:00',
#  '2025-10-27 03:00:00',
#  '2025-10-27 04:00:00',
#  '2025-10-27 05:00:00',
#  '2025-10-27 06:00:00',
#  '2025-10-27 07:00:00',
#  '2025-10-27 08:00:00',
#  '2025-10-27 09:00:00',
#  '2025-10-27 10:00:00',
#  '2025-10-27 11:00:00',
#  '2025-10-27 12:00:00',
#  '2025-10-27 13:00:00',
#  '2025-10-27 14:00:00',
#  '2025-10-27 15:00:00',
#  '2025-10-27 16:00:00',
#  '2025-10-27 17:00:00',
#  '2025-10-27 18:00:00',
#  '2025-10-27 19:00:00',
#  '2025-10-27 20:00:00',
#  '2025-10-27 21:00:00',
#  '2025-10-27 22:00:00',
#  '2025-10-27 23:00:00',
#  '2025-10-28 00:00:00',
#  '2025-10-28 01:00:00',
#  '2025-10-28 02:00:00',
#  '2025-10-28 03:00:00',
#  '2025-10-28 04:00:00',
#  '2025-10-28 05:00:00',
#  '2025-10-28 06:00:00',
#  '2025-10-28 07:00:00',
#  '2025-10-28 08:00:00',
#  '2025-10-28 09:00:00',
#  '2025-10-28 10:00:00',
#  '2025-10-28 11:00:00',
#  '2025-10-28 12:00:00',
#  '2025-10-28 13:00:00',
#  '2025-10-28 14:00:00',
#  '2025-10-28 15:00:00',
#  '2025-10-28 16:00:00',
#  '2025-10-28 17:00:00',
#  '2025-10-28 18:00:00',
#  '2025-10-28 19:00:00',
#  '2025-10-28 20:00:00',
#  '2025-10-28 21:00:00',
#  '2025-10-28 22:00:00',
#  '2025-10-28 23:00:00',
#  '2025-10-29 00:00:00',
#  '2025-10-29 01:00:00',
#  '2025-10-29 02:00:00',
#  '2025-10-29 03:00:00',
#  '2025-10-29 04:00:00',
#  '2025-10-29 05:00:00',
#  '2025-10-29 06:00:00',
#  '2025-10-29 07:00:00',
#  '2025-10-29 08:00:00',
#  '2025-10-29 09:00:00',
#  '2025-10-29 10:00:00',
#  '2025-10-29 11:00:00',
#  '2025-10-29 12:00:00',
#  '2025-10-29 13:00:00',
#  '2025-10-29 14:00:00',
#  '2025-10-29 15:00:00',
#  '2025-10-29 16:00:00',
#  '2025-10-29 17:00:00',
#  '2025-10-29 18:00:00',
#  '2025-10-29 19:00:00',
#  '2025-10-29 20:00:00',
#  '2025-10-29 21:00:00',
#  '2025-10-29 22:00:00',
#  '2025-10-29 23:00:00',
#  '2025-10-30 00:00:00',
#  '2025-10-30 01:00:00',
#  '2025-10-30 02:00:00',
#  '2025-10-30 03:00:00',
#  '2025-10-30 04:00:00',
#  '2025-10-30 05:00:00',
#  '2025-10-30 06:00:00',
#  '2025-10-30 07:00:00',
#  '2025-10-30 08:00:00',
#  '2025-10-30 09:00:00',
#  '2025-10-30 10:00:00',
#  '2025-10-30 11:00:00',
#  '2025-10-30 12:00:00',
#  '2025-10-30 13:00:00',
#  '2025-10-30 14:00:00',
#  '2025-10-30 15:00:00',
#  '2025-10-30 16:00:00',
#  '2025-10-30 17:00:00',
#  '2025-10-30 18:00:00',
#  '2025-10-30 19:00:00',
#  '2025-10-30 20:00:00',
#  '2025-10-30 21:00:00',
#  '2025-10-30 22:00:00',
#  '2025-10-30 23:00:00',
#  '2025-10-31 00:00:00',
#  '2025-10-31 01:00:00',
#  '2025-10-31 02:00:00',
#  '2025-10-31 03:00:00',
#  '2025-10-31 04:00:00',
#  '2025-10-31 05:00:00',
#  '2025-10-31 06:00:00',
#  '2025-10-31 07:00:00',
#  '2025-10-31 08:00:00',
#  '2025-10-31 09:00:00',
#  '2025-10-31 10:00:00',
#  '2025-10-31 11:00:00',
#  '2025-10-31 12:00:00',
#  '2025-10-31 13:00:00',
#  '2025-10-31 14:00:00',
#  '2025-10-31 15:00:00',
#  '2025-10-31 16:00:00',
#  '2025-10-31 17:00:00',
#  '2025-10-31 18:00:00',
#  '2025-10-31 19:00:00',
#  '2025-10-31 20:00:00',
#  '2025-10-31 21:00:00',
#  '2025-10-31 22:00:00',
#  '2025-10-31 23:00:00',
#  '2025-11-01 00:00:00',
#  '2025-11-01 01:00:00',
#  '2025-11-01 02:00:00',
#  '2025-11-01 03:00:00',
#  '2025-11-01 04:00:00',
#  '2025-11-01 05:00:00',
#  '2025-11-01 06:00:00',
#  '2025-11-01 07:00:00',
#  '2025-11-01 08:00:00',
#  '2025-11-01 09:00:00',
#  '2025-11-01 10:00:00',
#  '2025-11-01 11:00:00',
#  '2025-11-01 12:00:00',
#  '2025-11-01 13:00:00',
#  '2025-11-01 14:00:00',
#  '2025-11-01 15:00:00',
#  '2025-11-01 16:00:00',
#  '2025-11-01 17:00:00',
#  '2025-11-01 18:00:00',
#  '2025-11-01 19:00:00',
#  '2025-11-01 20:00:00',
#  '2025-11-01 21:00:00',
#  '2025-11-01 22:00:00',
#  '2025-11-01 23:00:00',
#  '2025-11-02 00:00:00',
#  '2025-11-02 01:00:00',
#  '2025-11-02 02:00:00',
#  '2025-11-02 03:00:00',
#  '2025-11-02 04:00:00',
#  '2025-11-02 05:00:00',
#  '2025-11-02 06:00:00',
#  '2025-11-02 07:00:00',
#  '2025-11-02 08:00:00',
#  '2025-11-02 09:00:00',
#  '2025-11-02 10:00:00',
#  '2025-11-02 11:00:00',
#  '2025-11-02 12:00:00',
#  '2025-11-02 13:00:00',
#  '2025-11-02 14:00:00',
#  '2025-11-02 15:00:00',
#  '2025-11-02 16:00:00',
#  '2025-11-02 17:00:00',
#  '2025-11-02 18:00:00',
#  '2025-11-02 19:00:00',
#  '2025-11-02 20:00:00',
#  '2025-11-02 21:00:00',
#  '2025-11-02 22:00:00',
#  '2025-11-02 23:00:00',
#  '2025-11-03 00:00:00',
#  '2025-11-03 01:00:00',
#  '2025-11-03 02:00:00',
#  '2025-11-03 03:00:00',
#  '2025-11-03 04:00:00',
#  '2025-11-03 05:00:00',
#  '2025-11-03 06:00:00',
#  '2025-11-03 07:00:00',
#  '2025-11-03 08:00:00',
#  '2025-11-03 09:00:00',
#  '2025-11-03 10:00:00',
#  '2025-11-03 11:00:00',
#  '2025-11-03 12:00:00',
#  '2025-11-03 13:00:00',
#  '2025-11-03 14:00:00',
#  '2025-11-03 15:00:00',
#  '2025-11-03 16:00:00',
#  '2025-11-03 17:00:00',
#  '2025-11-03 18:00:00',
#  '2025-11-03 19:00:00',
#  '2025-11-03 20:00:00',
#  '2025-11-03 21:00:00',
#  '2025-11-03 22:00:00',
#  '2025-11-03 23:00:00',
#  '2025-11-04 00:00:00',
#  '2025-11-04 01:00:00',
#  '2025-11-04 02:00:00',
#  '2025-11-04 03:00:00',
#  '2025-11-04 04:00:00',
#  '2025-11-04 05:00:00',
#  '2025-11-04 06:00:00',
#  '2025-11-04 07:00:00',
#  '2025-11-04 08:00:00',
#  '2025-11-04 09:00:00',
#  '2025-11-04 10:00:00',
#  '2025-11-04 11:00:00',
#  '2025-11-04 12:00:00',
#  '2025-11-04 13:00:00',
#  '2025-11-04 14:00:00',
#  '2025-11-04 15:00:00',
#  '2025-11-04 16:00:00',
#  '2025-11-04 17:00:00',
#  '2025-11-04 18:00:00',
#  '2025-11-04 19:00:00',
#  '2025-11-04 20:00:00',
#  '2025-11-04 21:00:00',
#  '2025-11-04 22:00:00',
#  '2025-11-04 23:00:00',
#  '2025-11-05 00:00:00',
#  '2025-11-05 01:00:00',
#  '2025-11-05 02:00:00',
#  '2025-11-05 03:00:00',
#  '2025-11-05 04:00:00',
#  '2025-11-05 05:00:00',
#  '2025-11-05 06:00:00',
#  '2025-11-05 07:00:00',
#  '2025-11-05 08:00:00',
#  '2025-11-05 09:00:00',
#  '2025-11-05 10:00:00',
#  '2025-11-05 11:00:00',
#  '2025-11-05 12:00:00',
#  '2025-11-05 13:00:00',
#  '2025-11-05 14:00:00',
#  '2025-11-05 15:00:00',
#  '2025-11-05 16:00:00',
#  '2025-11-05 17:00:00',
#  '2025-11-05 18:00:00',
#  '2025-11-05 19:00:00',
#  '2025-11-05 20:00:00',
#  '2025-11-05 21:00:00',
#  '2025-11-05 22:00:00',
#  '2025-11-05 23:00:00',
#  '2025-11-06 00:00:00',
#  '2025-11-06 01:00:00',
#  '2025-11-06 02:00:00',
#  '2025-11-06 03:00:00',
#  '2025-11-06 04:00:00',
#  '2025-11-06 05:00:00',
#  '2025-11-06 06:00:00',
#  '2025-11-06 07:00:00',
#  '2025-11-06 08:00:00',
#  '2025-11-06 09:00:00',
#  '2025-11-06 10:00:00',
#  '2025-11-06 11:00:00',
#  '2025-11-06 12:00:00',
#  '2025-11-06 13:00:00',
#  '2025-11-06 14:00:00',
#  '2025-11-06 15:00:00',
#  '2025-11-06 16:00:00',
#  '2025-11-06 17:00:00',
#  '2025-11-06 18:00:00',
#  '2025-11-06 19:00:00',
#  '2025-11-06 20:00:00',
#  '2025-11-06 21:00:00',
#  '2025-11-06 22:00:00',
#  '2025-11-06 23:00:00',
#  '2025-11-07 00:00:00',
#  '2025-11-07 01:00:00',
#  '2025-11-07 02:00:00',
#  '2025-11-07 03:00:00',
#  '2025-11-07 04:00:00',
#  '2025-11-07 05:00:00',
#  '2025-11-07 06:00:00',
#  '2025-11-07 07:00:00',
#  '2025-11-07 08:00:00',
#  '2025-11-07 09:00:00',
#  '2025-11-07 10:00:00',
#  '2025-11-07 11:00:00',
#  '2025-11-07 12:00:00',
#  '2025-11-07 13:00:00',
#  '2025-11-07 14:00:00',
#  '2025-11-07 15:00:00',
#  '2025-11-07 16:00:00',
#  '2025-11-07 17:00:00',
#  '2025-11-07 18:00:00',
#  '2025-11-07 19:00:00',
#  '2025-11-07 20:00:00',
#  '2025-11-07 21:00:00',
#  '2025-11-07 22:00:00',
#  '2025-11-07 23:00:00',
#  '2025-11-08 00:00:00',
#  '2025-11-08 01:00:00',
#  '2025-11-08 02:00:00',
#  '2025-11-08 03:00:00',
#  '2025-11-08 04:00:00',
#  '2025-11-08 05:00:00',
#  '2025-11-08 06:00:00',
#  '2025-11-08 07:00:00',
#  '2025-11-08 08:00:00',
#  '2025-11-08 09:00:00',
#  '2025-11-08 10:00:00',
#  '2025-11-08 11:00:00',
#  '2025-11-08 12:00:00',
#  '2025-11-08 13:00:00',
#  '2025-11-08 14:00:00',
#  '2025-11-08 15:00:00',
#  '2025-11-08 16:00:00',
#  '2025-11-08 17:00:00',
#  '2025-11-08 18:00:00',
#  '2025-11-08 19:00:00',
#  '2025-11-08 20:00:00',
#  '2025-11-08 21:00:00',
#  '2025-11-08 22:00:00',
#  '2025-11-08 23:00:00',
#  '2025-11-09 00:00:00',
#  '2025-11-09 01:00:00',
#  '2025-11-09 02:00:00',
#  '2025-11-09 03:00:00',
#  '2025-11-09 04:00:00',
#  '2025-11-09 05:00:00',
#  '2025-11-09 06:00:00',
#  '2025-11-09 07:00:00',
#  '2025-11-09 08:00:00',
#  '2025-11-09 09:00:00',
#  '2025-11-09 10:00:00',
#  '2025-11-09 11:00:00',
#  '2025-11-09 12:00:00',
#  '2025-11-09 13:00:00',
#  '2025-11-09 14:00:00',
#  '2025-11-09 15:00:00',
#  '2025-11-09 16:00:00',
#  '2025-11-09 17:00:00',
#  '2025-11-09 18:00:00',
#  '2025-11-09 19:00:00',
#  '2025-11-09 20:00:00',
#  '2025-11-09 21:00:00',
#  '2025-11-09 22:00:00',
#  '2025-11-09 23:00:00',
#  '2025-11-10 00:00:00',
#  '2025-11-10 01:00:00',
#  '2025-11-10 02:00:00',
#  '2025-11-10 03:00:00',
#  '2025-11-10 04:00:00',
#  '2025-11-10 05:00:00',
#  '2025-11-10 06:00:00',
#  '2025-11-10 07:00:00',
#  '2025-11-10 08:00:00',
#  '2025-11-10 09:00:00',
#  '2025-11-10 10:00:00',
#  '2025-11-10 11:00:00',
#  '2025-11-10 12:00:00',
#  '2025-11-10 13:00:00',
#  '2025-11-10 14:00:00',
#  '2025-11-10 15:00:00',
#  '2025-11-10 16:00:00',
#  '2025-11-10 17:00:00',
#  '2025-11-10 18:00:00',
#  '2025-11-10 19:00:00',
#  '2025-11-10 20:00:00',
#  '2025-11-10 21:00:00',
#  '2025-11-10 22:00:00',
#  '2025-11-10 23:00:00',
#  '2025-11-11 00:00:00',
#  '2025-11-11 01:00:00',
#  '2025-11-11 02:00:00',
#  '2025-11-11 03:00:00',
#  '2025-11-11 04:00:00',
#  '2025-11-11 05:00:00',
#  '2025-11-11 06:00:00',
#  '2025-11-11 07:00:00',
#  '2025-11-11 08:00:00',
#  '2025-11-11 09:00:00',
#  '2025-11-11 10:00:00',
#  '2025-11-11 11:00:00',
#  '2025-11-11 12:00:00',
#  '2025-11-11 13:00:00',
#  '2025-11-11 14:00:00',
#  '2025-11-11 15:00:00']

# %%
stats = items[cols + [target]].fillna(0).drop(target, axis=1).T.describe().T

# %%
stats[target] = items[target]
stats["item"] = items["item"]
stats
# Out:
#       count       mean         std  min  25%  50%    75%    max       type  \
# 0     980.0   0.034694    0.307915  0.0  0.0  0.0   0.00    6.0  Autograph
# 1     980.0   0.210204    0.713719  0.0  0.0  0.0   0.00    9.0  Autograph
# 2     980.0  19.751020   52.402984  0.0  0.0  1.0  15.25  797.0  Autograph
# 3     980.0   0.316327    1.012657  0.0  0.0  0.0   0.00   15.0      Other
# 4     980.0   0.010204    0.110241  0.0  0.0  0.0   0.00    2.0  Autograph
# ...     ...        ...         ...  ...  ...  ...    ...    ...        ...
# 6588  980.0   6.171429   15.768732  0.0  0.0  0.0   4.00  205.0  Autograph
# 6589  980.0   7.309184   17.008419  0.0  0.0  0.0   5.00  240.0  Autograph
# 6590  980.0  21.969388   47.022489  0.0  0.0  1.0  12.25  272.0       Team
# 6591  980.0   6.485714   15.797195  0.0  0.0  0.0   4.00  172.0  Autograph
# 6592  980.0  66.287755  130.515505  0.0  2.0  6.0  54.25  801.0  Autograph
#
#                                          item
# 0       Sticker | Hobbit (Foil) | London 2018
# 1         Sticker | HooXi (Gold) | Paris 2023
# 2           Sticker | HooXi | Copenhagen 2024
# 3            Sticker | Hypnotic Surf K (Foil)
# 4         Sticker | Kaze (Foil) | Boston 2018
# ...                                       ...
# 6588         Sticker | tabseN | Shanghai 2024
# 6589  Sticker | kyxsan (Holo) | Shanghai 2024
# 6590  Sticker | HEROIC (Holo) | Shanghai 2024
# 6591  Sticker | ICY (Glitter) | Shanghai 2024
# 6592         Sticker | sjuush | Shanghai 2024
#
# [6593 rows x 10 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(stats, test_size=0.2, random_state=41)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(train.drop([target, 'item'], axis=1), train[target])
classes = model.predict(test.drop([target, 'item'], axis=1))
multi_target_forest = MultiOutputClassifier(model, n_jobs=2)

# %%
out = pd.DataFrame(classes, columns=['predicted'])
out['actual'] = test[target].reset_index(drop=True)
out['item'] = test['item'].reset_index(drop=True)

# %%
for t in  out["actual"].unique():
    important = out[(out["actual"] == t) | (out["predicted"] == t)].drop('item', axis=1)
    TP = len(important[important == t].dropna())
    TN = len(out) - len(important)
    FN = len(important[(important['actual'] == t) & (important['predicted'] != t)])
    FP = len(important[(important['actual'] != t) & (important['predicted'] == t)])
    print(t, TP, FP, FN, TN)
# Out:
# Autograph 888 206 67 158
# Other 68 19 61 1171
# Team 60 77 167 1015
# Event 0 1 8 1310

# %%
autographs = duckdb.query("select * from stkr where type = 'Autograph'").df()
autographs.head()
# Out:
#                  date  price  volume                                    item  \
# 0 2019-08-14 01:00:00  0.818      35  Sticker | Aleksib (Foil) | Berlin 2019
# 1 2019-08-15 01:00:00  0.745     127  Sticker | Aleksib (Foil) | Berlin 2019
# 2 2019-08-16 01:00:00  0.789      54  Sticker | Aleksib (Foil) | Berlin 2019
# 3 2019-08-17 01:00:00  0.893      57  Sticker | Aleksib (Foil) | Berlin 2019
# 4 2019-08-18 01:00:00  0.826      55  Sticker | Aleksib (Foil) | Berlin 2019
#
#         type effect                        market_hash_name      rarity  \
# 0  Autograph   Foil  Sticker | Aleksib (Foil) | Berlin 2019  Remarkable
# 1  Autograph   Foil  Sticker | Aleksib (Foil) | Berlin 2019  Remarkable
# 2  Autograph   Foil  Sticker | Aleksib (Foil) | Berlin 2019  Remarkable
# 3  Autograph   Foil  Sticker | Aleksib (Foil) | Berlin 2019  Remarkable
# 4  Autograph   Foil  Sticker | Aleksib (Foil) | Berlin 2019  Remarkable
#
#    tournament_id              tournament  team_id team_tag  team  \
# 0           16.0  2019 StarLadder Berlin     84.0     ENCE  ENCE
# 1           16.0  2019 StarLadder Berlin     84.0     ENCE  ENCE
# 2           16.0  2019 StarLadder Berlin     84.0     ENCE  ENCE
# 3           16.0  2019 StarLadder Berlin     84.0     ENCE  ENCE
# 4           16.0  2019 StarLadder Berlin     84.0     ENCE  ENCE
#
#                                            image_url rarity_color
# 0  https://community.akamai.steamstatic.com/econo...       purple
# 1  https://community.akamai.steamstatic.com/econo...       purple
# 2  https://community.akamai.steamstatic.com/econo...       purple
# 3  https://community.akamai.steamstatic.com/econo...       purple
# 4  https://community.akamai.steamstatic.com/econo...       purple

# %%
names = duckdb.query("select distinct item from autographs where type = 'Autograph'").df()

# %%
parsed = {name[0]: re.match(r'Sticker \| (([^\(|\|])+)',name[0]).group(1).strip() for name in names.values.tolist()}

mappings = pd.Series(parsed).to_frame().reset_index()

mappings.columns = ["sticker_name", 'player']

duckdb.query("select * from autographs join mappings on autographs.item = mappings.sticker_name").df().drop(
    columns=['type', 'market_hash_name', 'image_url', 'sticker_name'], axis=1
).to_parquet('../autographs.parquet')

# %%
match =  ParquetFile("../matches.parquet").to_pandas()

# %%
pvt = duckdb.query('select price, volume, date, item from stkr where tournament is not null').df().pivot(index='item', columns = 'date', values = 'price')
pvt =  pvt.reset_index()
# Out:
# date                                       2014-08-05 01:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                            NaN
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2014-08-06 01:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                            NaN
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2014-08-07 01:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                            NaN
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2014-08-08 01:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                            NaN
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2014-08-09 01:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                            NaN
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2014-08-10 01:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                            NaN
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2014-08-11 01:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                            NaN
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2014-08-12 01:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                            NaN
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2014-08-13 01:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                            NaN
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2014-08-14 01:00:00  ...  \
# item                                                            ...
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN  ...
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN  ...
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN  ...
# Sticker | 3DMAX | Shanghai 2024                            NaN  ...
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN  ...
# ...                                                        ...  ...
# Sticker | zorte | Paris 2023                               NaN  ...
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN  ...
# Sticker | ztr (Gold) | Shanghai 2024                       NaN  ...
# Sticker | ztr (Holo) | Shanghai 2024                       NaN  ...
# Sticker | ztr | Shanghai 2024                              NaN  ...
#
# date                                       2025-11-12 00:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                0.538
# Sticker | 3DMAX (Gold) | Shanghai 2024                   2.959
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                          0.030
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2025-11-12 01:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                0.555
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                          0.040
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                  0.050
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2025-11-12 02:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                0.555
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                          0.030
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2025-11-12 03:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                 0.54
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                           0.03
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2025-11-12 04:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN
# Sticker | 3DMAX (Gold) | Shanghai 2024                    2.95
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                           0.03
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2025-11-12 05:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                0.549
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                   5.780
# Sticker | 3DMAX | Shanghai 2024                          0.030
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2025-11-12 06:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                 0.54
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                           0.03
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2025-11-12 07:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                0.540
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                          0.040
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                  0.035
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                            0.030
#
# date                                       2025-11-12 08:00:00  \
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                0.544
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                          0.030
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# date                                       2025-11-12 09:00:00
# item
# Sticker | 3DMAX (Glitter) | Shanghai 2024                  NaN
# Sticker | 3DMAX (Gold) | Shanghai 2024                     NaN
# Sticker | 3DMAX (Holo) | Shanghai 2024                     NaN
# Sticker | 3DMAX | Shanghai 2024                            NaN
# Sticker | 910 (Glitter) | Shanghai 2024                    NaN
# ...                                                        ...
# Sticker | zorte | Paris 2023                               NaN
# Sticker | ztr (Glitter) | Shanghai 2024                    NaN
# Sticker | ztr (Gold) | Shanghai 2024                       NaN
# Sticker | ztr (Holo) | Shanghai 2024                       NaN
# Sticker | ztr | Shanghai 2024                              NaN
#
# [6011 rows x 4845 columns]

# %%
pvt_price = duckdb.query('select * from stkr where team_tag is not null').df().pivot(index='item', columns = 'date', values = 'price').reset_index()

match =  ParquetFile("../matches.parquet").to_pandas()
match['date'] = pd.to_datetime(match['date'], format='mixed')

match
# Out:
#           date                          event  event-id             winner  \
# 0   2015-03-15          ESL One Katowice 2015      1611             Fnatic
# 1   2015-03-14          ESL One Katowice 2015      1611  Ninjas in Pyjamas
# 2   2015-03-14          ESL One Katowice 2015      1611             Fnatic
# 3   2015-03-14          ESL One Katowice 2015      1611  Ninjas in Pyjamas
# 4   2015-03-13          ESL One Katowice 2015      1611         Virtus.Pro
# ..         ...                            ...       ...                ...
# 691 2024-03-21  PGL CS2 Major Copenhagen 2024      7148  Complexity Gaming
# 692 2024-03-21  PGL CS2 Major Copenhagen 2024      7148       Eternal Fire
# 693 2024-03-21  PGL CS2 Major Copenhagen 2024      7148   Imperial Esports
# 694 2024-03-21  PGL CS2 Major Copenhagen 2024      7148               MOUZ
# 695 2024-03-21  PGL CS2 Major Copenhagen 2024      7148      Natus Vincere
#
#                  loser  winner-score  loser-score  \
# 0    Ninjas in Pyjamas             2            1
# 1          Team EnVyUs             2            0
# 2           Virtus.Pro             2            0
# 3          TSM Kinguin             2            1
# 4           Keyd Stars             2            1
# ..                 ...           ...          ...
# 691        paiN Gaming            13            9
# 692           Vitality            13           10
# 693         Virtus.Pro            13            6
# 694           ECSTATIC            13           11
# 695        The MongolZ            13           10
#
#                                                  stats
# 0    https://www.hltv.org/matches/2294629/fnatic-vs...
# 1    https://www.hltv.org/matches/2294628/envy-vs-n...
# 2    https://www.hltv.org/matches/2294627/fnatic-vs...
# 3    https://www.hltv.org/matches/2294626/ninjas-in...
# 4    https://www.hltv.org/matches/2294625/virtuspro...
# ..                                                 ...
# 691  https://www.hltv.org/matches/2370633/complexit...
# 692  https://www.hltv.org/matches/2370630/vitality-...
# 693  https://www.hltv.org/matches/2370631/virtuspro...
# 694  https://www.hltv.org/matches/2370628/mouz-vs-e...
# 695  https://www.hltv.org/matches/2370629/natus-vin...
#
# [696 rows x 8 columns]

# %%
pvt_price.reset_index(inplace=True)

# %%
event_wins = match[['event', 'winner']]
top_3  = duckdb.query("""
    select event, winner from (SELECT
        event,
        winner,
        win_count,
        RANK() OVER (
            PARTITION BY event
            ORDER BY win_count DESC
        ) AS rank
    FROM (
        SELECT
            event,
            winner,
            COUNT(*) AS win_count
        FROM event_wins
        GROUP BY event, winner
    ))
        WHERE RANK <= 3
""").df()

# %%
lengths = duckdb.query("select event, min(date) as start_date, max(date) as end_date from match group by event").df()

# %%
data = {}
for event in match["event"].unique():
    timeframe = lengths.set_index('event').loc[event]
    teams = duckdb.query(f"select distinct winner from match where event = '{event}' UNION select distinct loser from match where event = '{event}'").df()

    team_stkrs = duckdb.query('select distinct item from stkr where team in (select winner from teams)').df()
    stkr_data = duckdb.query('select * from pvt_price where item in (select item from team_stkrs)').df()

    stkr_data = stkr_data[stkr_data.min().dropna().index]
    t = stkr_data.T.reset_index().iloc[1:]
    t['index'] = pd.to_datetime(t['index'])
    t = duckdb.query(f"""select * from t where index > '{str(timeframe['start_date'].date() - timedelta(50))}' and  index < '{str(timeframe['end_date'])}'""").df().T
    t.columns = list(t.loc['index'])
    t = t.iloc[1:]
    t['item'] = list(stkr_data['item'])
    t = t[t.drop('item',axis=1).T.isnull().apply(lambda x: not all(x))]
    stkr_data = duckdb.query('select * from t join (select distinct team, item from stkr) as t2 on t2.item = t.item').df().drop('item_1', axis=1)
    n = stkr_data.drop(['item', 'team'], axis=1)
    zs = (n.sub(n.mean(axis=1),axis=0)).div(n.std(axis=1), axis=0)
    zs['team'] = stkr_data['team']
    zm = zs.groupby('team').mean().reset_index()
    zm['top_team'] = zm['team'].isin(top_3[top_3['event'] == event]['winner'])
    data[event] = zm[list(zm.columns[-21:]) + ["team"]]

# %%
from sklearn.ensemble import RandomForestClassifier
predictions = []
for event in data.keys():
    if data[event].empty:
        print(event, "is empty")
        continue
    d = []
    for e in data.keys():
        if e is not event:
            d.append(pd.DataFrame(data[e].to_numpy()))
    d = pd.concat(d).dropna()
    if len(d.columns) != len(data[event].columns):
        print(event, "Has col mismatch")
        continue
    model = RandomForestClassifier(n_estimators=100, random_state=42)
    model.fit(d.drop([20,21], axis=1).astype(float), d[20].astype(bool))
    pred = model.predict(pd.DataFrame(data[event].drop(['team', 'top_team'], axis=1).to_numpy()).astype(float))
    predictions.append((list(pred), list(data[event]['top_team'])))
# Out:
# 2014 EMS One Katowice is empty
# 2014 ESL One Cologne Has col mismatch

# %%
preds = pd.concat([pd.DataFrame(p) for p in predictions], axis=1).T
preds.columns = ["prediction", "actual"]
# Out:
#     prediction  actual
# 0        False   False
# 1        False    True
# 2        False   False
# 3         True   False
# 4        False   False
# ..         ...     ...
# 10       False   False
# 11       False   False
# 12       False   False
# 13       False    True
# 14       False   False
#
# [265 rows x 2 columns]

# %%
TP = len(preds[preds['prediction'] & preds['actual']])
TN = len(preds[(preds['prediction'] == False) & (preds['actual'] == False)])
FP = len(preds[(preds['prediction']) & (preds['actual'] == False)])
FN = len(preds[(preds['prediction'] == False) & (preds['actual'])])
print(TP, FP, FN, TN)

acc = (TP + TN) / (TP + TN + FP + FN)
prec = TP / (TP + FP)
rec = TP / (TP + FN)
f1 = 2 * prec * rec / (prec + rec)

print("Accuracy", acc)
print("Precision", prec)
print("Recall", rec)
print("F1", f1)
# Out:
# 33 14 38 180
# Accuracy 0.8037735849056604
# Precision 0.7021276595744681
# Recall 0.4647887323943662
# F1 0.559322033898305
