# %%
from json import loads,dump
import pandas as pd
from urllib.parse import quote as urlquote
from requests import get
from time import sleep

# %%
items = list(loads(open("cs2-items.json","rb").read()).keys())

# %%
login_token = "76561198304659319%7C%7CeyAidHlwIjogIkpXVCIsICJhbGciOiAiRWREU0EiIH0..z38TYhTZO_CQXPuAlvI3wrDgq3cRLAyR0KdYKxju1oSnHOnd1tur-CJHDPq8aldz7i5NR_Du614YuucBh81XDA; sessionid=681c88839b799b2040f4360b;"

# %%
for i in range(len(items)):
    item_id = items[i]
    print("Querying ",i, item_id)
    res = get(url=f"https://steamcommunity.com/market/pricehistory/?appid=730&market_hash_name={urlquote(item_id)}", cookies={"steamLoginSecure": login_token})

    if res.status_code != 200:
        print(f"Bad Response Code: {res.status_code} on item: {item_id}")
        break
    data = res.json()
    data["id"] = item_id
    with open(f"./data/{i}.json", "w") as f:
        dump(fp=f,obj=data)
        f.close()
        print("saved")
    sleep(0.5)
# Out:
# Querying  10123 Sticker | Aleksib (Foil) | Berlin 2019
# saved
# Querying  10124 Sticker | Aleksib (Foil) | Katowice 2019
# saved
# Querying  10125 Sticker | Aleksib (Glitter) | Antwerp 2022
# saved
# Querying  10126 Sticker | Aleksib (Glitter) | Copenhagen 2024
# saved
# Querying  10127 Sticker | Aleksib (Glitter) | Paris 2023
# saved
# Querying  10128 Sticker | Aleksib (Glitter) | Rio 2022
# saved
# Querying  10129 Sticker | Aleksib (Glitter, Champion) | Copenhagen 2024
# saved
# Querying  10130 Sticker | Aleksib (Gold) | Antwerp 2022
# saved
# Querying  10131 Sticker | Aleksib (Gold) | Berlin 2019
# saved
# Querying  10132 Sticker | Aleksib (Gold) | Copenhagen 2024
# saved
# Querying  10133 Sticker | Aleksib (Gold) | Katowice 2019
# saved
# Querying  10134 Sticker | Aleksib (Gold) | Paris 2023
# saved
# Querying  10135 Sticker | Aleksib (Gold) | Rio 2022
# saved
# Querying  10136 Sticker | Aleksib (Gold, Champion) | Copenhagen 2024
# saved
# Querying  10137 Sticker | Aleksib (Holo) | Antwerp 2022
# saved
# Querying  10138 Sticker | Aleksib (Holo) | Copenhagen 2024
# saved
# Querying  10139 Sticker | Aleksib (Holo) | Paris 2023
# saved
# Querying  10140 Sticker | Aleksib (Holo) | Rio 2022
# saved
# Querying  10141 Sticker | Aleksib (Holo, Champion) | Copenhagen 2024
# saved
# Querying  10142 Sticker | Aleksib | Antwerp 2022
# saved
# Querying  10143 Sticker | Aleksib | Berlin 2019
# saved
# Querying  10144 Sticker | Aleksib | Copenhagen 2024
# saved
# Querying  10145 Sticker | Aleksib | Katowice 2019
# saved
# Querying  10146 Sticker | Aleksib | Paris 2023
# saved
# Querying  10147 Sticker | Aleksib | Rio 2022
# saved
# Querying  10148 Sticker | All Hail the King (Foil)
# saved
# Querying  10149 Sticker | AmaNEk (Foil) | Berlin 2019
# saved
# Querying  10150 Sticker | AmaNEk (Foil) | Boston 2018
# saved
# Querying  10151 Sticker | AmaNEk (Gold) | Berlin 2019
# saved
# Querying  10152 Sticker | AmaNEk (Gold) | Boston 2018
# saved
# Querying  10153 Sticker | AmaNEk | Berlin 2019
# saved
# Querying  10154 Sticker | AmaNEk | Boston 2018
# saved
# Querying  10155 Sticker | Ancient Beast
# saved
# Querying  10156 Sticker | Ancient Beast (Foil)
# saved
# Querying  10157 Sticker | Ancient Marauder
# saved
# Querying  10158 Sticker | Ancient Protector
# saved
# Querying  10159 Sticker | Angry T
# saved
# Querying  10160 Sticker | Apeks (Glitter) | Copenhagen 2024
# saved
# Querying  10161 Sticker | Apeks (Glitter) | Paris 2023
# saved
# Querying  10162 Sticker | Apeks (Gold) | Copenhagen 2024
# saved
# Querying  10163 Sticker | Apeks (Gold) | Paris 2023
# saved
# Querying  10164 Sticker | Apeks (Holo) | Copenhagen 2024
# saved
# Querying  10165 Sticker | Apeks (Holo) | Paris 2023
# saved
# Querying  10166 Sticker | Apeks | Copenhagen 2024
# saved
# Querying  10167 Sticker | Apeks | Paris 2023
# saved
# Querying  10168 Sticker | Approaching Site (Foil)
# saved
# Querying  10169 Sticker | Arms Race
# saved
# Querying  10170 Sticker | Assassin
# saved
# Querying  10171 Sticker | Assassin (Holo)
# saved
# Querying  10172 Sticker | Astralis (Foil) | 2020 RMR
# saved
# Querying  10173 Sticker | Astralis (Foil) | Atlanta 2017
# saved
# Querying  10174 Sticker | Astralis (Foil) | Berlin 2019
# saved
# Querying  10175 Sticker | Astralis (Foil) | Boston 2018
# saved
# Querying  10176 Sticker | Astralis (Foil) | Cologne 2016
# saved
# Querying  10177 Sticker | Astralis (Foil) | Katowice 2019
# saved
# Querying  10178 Sticker | Astralis (Foil) | Krakow 2017
# saved
# Querying  10179 Sticker | Astralis (Foil) | London 2018
# saved
# Querying  10180 Sticker | Astralis (Foil) | MLG Columbus 2016
# saved
# Querying  10181 Sticker | Astralis (Foil) | Stockholm 2021
# saved
# Querying  10182 Sticker | Astralis (Glitter) | Antwerp 2022
# saved
# Querying  10183 Sticker | Astralis (Gold) | 2020 RMR
# saved
# Querying  10184 Sticker | Astralis (Gold) | Antwerp 2022
# saved
# Querying  10185 Sticker | Astralis (Gold) | Stockholm 2021
# saved
# Querying  10186 Sticker | Astralis (Holo) | 2020 RMR
# saved
# Querying  10187 Sticker | Astralis (Holo) | Antwerp 2022
# saved
# Querying  10188 Sticker | Astralis (Holo) | Atlanta 2017
# saved
# Querying  10189 Sticker | Astralis (Holo) | Berlin 2019
# saved
# Querying  10190 Sticker | Astralis (Holo) | Boston 2018
# saved
# Querying  10191 Sticker | Astralis (Holo) | Cologne 2016
# saved
# Querying  10192 Sticker | Astralis (Holo) | Katowice 2019
# saved
# Querying  10193 Sticker | Astralis (Holo) | Krakow 2017
# saved
# Querying  10194 Sticker | Astralis (Holo) | London 2018
# saved
# Querying  10195 Sticker | Astralis (Holo) | MLG Columbus 2016
# saved
# Querying  10196 Sticker | Astralis (Holo) | Stockholm 2021
# saved
# Querying  10197 Sticker | Astralis | 2020 RMR
# saved
# Querying  10198 Sticker | Astralis | Antwerp 2022
# saved
# Querying  10199 Sticker | Astralis | Atlanta 2017
# saved
# Querying  10200 Sticker | Astralis | Berlin 2019
# saved
# Querying  10201 Sticker | Astralis | Boston 2018
# saved
# Querying  10202 Sticker | Astralis | Cologne 2016
# saved
# Querying  10203 Sticker | Astralis | Katowice 2019
# saved
# Querying  10204 Sticker | Astralis | Krakow 2017
# saved
# Querying  10205 Sticker | Astralis | London 2018
# saved
# Querying  10206 Sticker | Astralis | MLG Columbus 2016
# saved
# Querying  10207 Sticker | Astralis | Stockholm 2021
# saved
# Querying  10208 Sticker | Attacker (Foil) | Berlin 2019
# saved
# Querying  10209 Sticker | Attacker (Foil) | Boston 2018
# saved
# Querying  10210 Sticker | Attacker (Foil) | Katowice 2019
# saved
# Querying  10211 Sticker | Attacker (Gold) | Berlin 2019
# saved
# Querying  10212 Sticker | Attacker (Gold) | Boston 2018
# saved
# Querying  10213 Sticker | Attacker (Gold) | Katowice 2019
# saved
# Querying  10214 Sticker | Attacker | Berlin 2019
# saved
# Querying  10215 Sticker | Attacker | Boston 2018
# saved
# Querying  10216 Sticker | Attacker | Katowice 2019
# saved
# Querying  10217 Sticker | Avangar (Foil) | Berlin 2019
# saved
# Querying  10218 Sticker | Avangar (Foil) | Boston 2018
# saved
# Querying  10219 Sticker | Avangar (Foil) | Katowice 2019
# saved
# Querying  10220 Sticker | Avangar (Holo) | Berlin 2019
# saved
# Querying  10221 Sticker | Avangar (Holo) | Boston 2018
# saved
# Querying  10222 Sticker | Avangar (Holo) | Katowice 2019
# saved
# Querying  10223 Sticker | Avangar | Berlin 2019
# saved
# Querying  10224 Sticker | Avangar | Boston 2018
# saved
# Querying  10225 Sticker | Avangar | Katowice 2019
# saved
# Querying  10226 Sticker | Awp Country
# saved
# Querying  10227 Sticker | Ax1Le (Glitter) | Antwerp 2022
# saved
# Querying  10228 Sticker | Ax1Le (Glitter) | Copenhagen 2024
# saved
# Querying  10229 Sticker | Ax1Le (Glitter) | Rio 2022
# saved
# Querying  10230 Sticker | Ax1Le (Gold) | Antwerp 2022
# saved
# Querying  10231 Sticker | Ax1Le (Gold) | Copenhagen 2024
# saved
# Querying  10232 Sticker | Ax1Le (Gold) | Rio 2022
# saved
# Querying  10233 Sticker | Ax1Le (Gold) | Stockholm 2021
# saved
# Querying  10234 Sticker | Ax1Le (Holo) | Antwerp 2022
# saved
# Querying  10235 Sticker | Ax1Le (Holo) | Copenhagen 2024
# saved
# Querying  10236 Sticker | Ax1Le (Holo) | Rio 2022
# saved
# Querying  10237 Sticker | Ax1Le (Holo) | Stockholm 2021
# saved
# Querying  10238 Sticker | Ax1Le | Antwerp 2022
# saved
# Querying  10239 Sticker | Ax1Le | Copenhagen 2024
# saved
# Querying  10240 Sticker | Ax1Le | Rio 2022
# saved
# Querying  10241 Sticker | Ax1Le | Stockholm 2021
# saved
# Querying  10242 Sticker | Aztec
# saved
# Querying  10243 Sticker | B Hop
# saved
# Querying  10244 Sticker | B-Day
# saved
# Querying  10245 Sticker | B1ad3 (Foil) | Atlanta 2017
# saved
# Querying  10246 Sticker | B1ad3 (Foil) | Boston 2018
# saved
# Querying  10247 Sticker | B1ad3 (Foil) | Cluj-Napoca 2015
# saved
# Querying  10248 Sticker | B1ad3 (Foil) | Cologne 2015
# saved
# Querying  10249 Sticker | B1ad3 (Foil) | Cologne 2016
# saved
# Querying  10250 Sticker | B1ad3 (Foil) | Krakow 2017
# saved
# Querying  10251 Sticker | B1ad3 (Foil) | MLG Columbus 2016
# saved
# Querying  10252 Sticker | B1ad3 (Gold) | Boston 2018
# saved
# Querying  10253 Sticker | B1ad3 (Gold) | Krakow 2017
# saved
# Querying  10254 Sticker | B1ad3 | Atlanta 2017
# saved
# Querying  10255 Sticker | B1ad3 | Boston 2018
# saved
# Querying  10256 Sticker | B1ad3 | Cluj-Napoca 2015
# saved
# Querying  10257 Sticker | B1ad3 | Cologne 2015
# saved
# Querying  10258 Sticker | B1ad3 | Cologne 2016
# saved
# Querying  10259 Sticker | B1ad3 | Krakow 2017
# saved
# Querying  10260 Sticker | B1ad3 | MLG Columbus 2016
# saved
# Querying  10261 Sticker | BF 2042
# saved
# Querying  10262 Sticker | BIG (Foil) | 2020 RMR
# saved
# Querying  10263 Sticker | BIG (Foil) | Boston 2018
# saved
# Querying  10264 Sticker | BIG (Foil) | Katowice 2019
# saved
# Querying  10265 Sticker | BIG (Foil) | Krakow 2017
# saved
# Querying  10266 Sticker | BIG (Foil) | London 2018
# saved
# Querying  10267 Sticker | BIG (Foil) | Stockholm 2021
# saved
# Querying  10268 Sticker | BIG (Glitter) | Antwerp 2022
# saved
# Querying  10269 Sticker | BIG (Glitter) | Rio 2022
# saved
# Querying  10270 Sticker | BIG (Gold) | 2020 RMR
# saved
# Querying  10271 Sticker | BIG (Gold) | Antwerp 2022
# saved
# Querying  10272 Sticker | BIG (Gold) | Rio 2022
# saved
# Querying  10273 Sticker | BIG (Gold) | Stockholm 2021
# saved
# Querying  10274 Sticker | BIG (Holo) | 2020 RMR
# saved
# Querying  10275 Sticker | BIG (Holo) | Antwerp 2022
# saved
# Querying  10276 Sticker | BIG (Holo) | Boston 2018
# saved
# Querying  10277 Sticker | BIG (Holo) | Katowice 2019
# saved
# Querying  10278 Sticker | BIG (Holo) | Krakow 2017
# saved
# Querying  10279 Sticker | BIG (Holo) | London 2018
# saved
# Querying  10280 Sticker | BIG (Holo) | Rio 2022
# saved
# Querying  10281 Sticker | BIG (Holo) | Stockholm 2021
# saved
# Querying  10282 Sticker | BIG | 2020 RMR
# saved
# Querying  10283 Sticker | BIG | Antwerp 2022
# saved
# Querying  10284 Sticker | BIG | Boston 2018
# saved
# Querying  10285 Sticker | BIG | Katowice 2019
# saved
# Querying  10286 Sticker | BIG | Krakow 2017
# saved
# Querying  10287 Sticker | BIG | London 2018
# saved
# Querying  10288 Sticker | BIG | Rio 2022
# saved
# Querying  10289 Sticker | BIG | Stockholm 2021
# saved
# Querying  10290 Sticker | BIT (Foil) | Boston 2018
# saved
# Querying  10291 Sticker | BIT (Gold) | Boston 2018
# saved
# Querying  10292 Sticker | BIT | Boston 2018
# saved
# Querying  10293 Sticker | BLAST.tv (Glitter) | Paris 2023
# saved
# Querying  10294 Sticker | BLAST.tv (Gold) | Paris 2023
# saved
# Querying  10295 Sticker | BLAST.tv (Holo) | Paris 2023
# saved
# Querying  10296 Sticker | BLAST.tv | Paris 2023
# saved
# Querying  10297 Sticker | BOROS (Glitter) | Paris 2023
# saved
# Querying  10298 Sticker | BOROS (Gold) | Paris 2023
# saved
# Querying  10299 Sticker | BOROS (Holo) | Paris 2023
# saved
# Querying  10300 Sticker | BOROS | Paris 2023
# saved
# Querying  10301 Sticker | BUDA (Glitter) | Rio 2022
# saved
# Querying  10302 Sticker | BUDA (Gold) | Rio 2022
# saved
# Querying  10303 Sticker | BUDA (Holo) | Rio 2022
# saved
# Querying  10304 Sticker | BUDA | Rio 2022
# saved
# Querying  10305 Sticker | Baaa-ckstabber!
# saved
# Querying  10306 Sticker | Baby Cerberus
# saved
# Querying  10307 Sticker | Baby Fire Serpent
# saved
# Querying  10308 Sticker | Baby Howl
# saved
# Querying  10309 Sticker | Baby Lore
# saved
# Querying  10310 Sticker | Baby Medusa
# saved
# Querying  10311 Sticker | Backstab
# saved
# Querying  10312 Sticker | Bad News Eagles (Glitter) | Antwerp 2022
# saved
# Querying  10313 Sticker | Bad News Eagles (Glitter) | Paris 2023
# saved
# Querying  10314 Sticker | Bad News Eagles (Glitter) | Rio 2022
# saved
# Querying  10315 Sticker | Bad News Eagles (Gold) | Antwerp 2022
# saved
# Querying  10316 Sticker | Bad News Eagles (Gold) | Paris 2023
# saved
# Querying  10317 Sticker | Bad News Eagles (Gold) | Rio 2022
# saved
# Querying  10318 Sticker | Bad News Eagles (Holo) | Antwerp 2022
# saved
# Querying  10319 Sticker | Bad News Eagles (Holo) | Paris 2023
# saved
# Querying  10320 Sticker | Bad News Eagles (Holo) | Rio 2022
# saved
# Querying  10321 Sticker | Bad News Eagles | Antwerp 2022
# saved
# Querying  10322 Sticker | Bad News Eagles | Paris 2023
# saved
# Querying  10323 Sticker | Bad News Eagles | Rio 2022
# saved
# Querying  10324 Sticker | Badge of Service
# saved
# Querying  10325 Sticker | Baited
# saved
# Querying  10326 Sticker | Baited (Holo)
# saved
# Querying  10327 Sticker | Banana
# saved
# Querying  10328 Sticker | Bart4k (Glitter) | Paris 2023
# saved
# Querying  10329 Sticker | Bart4k (Gold) | Paris 2023
# saved
# Querying  10330 Sticker | Bart4k (Holo) | Paris 2023
# saved
# Querying  10331 Sticker | Bart4k | Paris 2023
# saved
# Querying  10332 Sticker | Bash (Holo)
# saved
# Querying  10333 Sticker | Basilisk
# saved
# Querying  10334 Sticker | Basilisk (Foil)
# saved
# Querying  10335 Sticker | Batter Up
# saved
# Querying  10336 Sticker | Battle Scarred
# saved
# Querying  10337 Sticker | Battle Scarred (Holo)
# saved
# Querying  10338 Sticker | Battlefield Portal
# saved
# Querying  10339 Sticker | Beaky Decade
# saved
# Querying  10340 Sticker | Big Clucks
# saved
# Querying  10341 Sticker | Big Clucks (Foil)
# saved
# Querying  10342 Sticker | Big Hugs
# saved
# Querying  10343 Sticker | Big Hugs (Holo)
# saved
# Querying  10344 Sticker | Bish (Holo)
# saved
# Querying  10345 Sticker | Bite Me
# saved
# Querying  10346 Sticker | Bite Me (Foil)
# saved
# Querying  10347 Sticker | Black Dog
# saved
# Querying  10348 Sticker | Black Jaggyfish
# saved
# Querying  10349 Sticker | Black Shark Shooter
# saved
# Querying  10350 Sticker | Blaze Surf K (Foil)
# saved
# Querying  10351 Sticker | Blitzkrieg
# saved
# Querying  10352 Sticker | Blood Boiler
# saved
# Querying  10353 Sticker | Blood Moon Tentaskull
# saved
# Querying  10354 Sticker | Blood Moon Wave Rider
# saved
# Querying  10355 Sticker | Bloodthirster (Foil)
# saved
# Querying  10356 Sticker | Blue Gem (Glitter)
# saved
# Querying  10357 Sticker | Blue Gnar
# saved
# Querying  10358 Sticker | Blue Lethal
# saved
# Querying  10359 Sticker | Blue Shark Shooter
# saved
# Querying  10360 Sticker | Blue Swallow
# saved
# Querying  10361 Sticker | BnTeT (Foil) | Berlin 2019
# saved
# Querying  10362 Sticker | BnTeT (Foil) | Boston 2018
# saved
# Querying  10363 Sticker | BnTeT (Foil) | Katowice 2019
# saved
# Querying  10364 Sticker | BnTeT (Foil) | London 2018
# saved
# Querying  10365 Sticker | BnTeT (Gold) | Berlin 2019
# saved
# Querying  10366 Sticker | BnTeT (Gold) | Boston 2018
# saved
# Querying  10367 Sticker | BnTeT (Gold) | Katowice 2019
# saved
# Querying  10368 Sticker | BnTeT (Gold) | London 2018
# saved
# Querying  10369 Sticker | BnTeT | Berlin 2019
# saved
# Querying  10370 Sticker | BnTeT | Boston 2018
# saved
# Querying  10371 Sticker | BnTeT | Katowice 2019
# saved
# Querying  10372 Sticker | BnTeT | London 2018
# saved
# Querying  10373 Sticker | Bomb Code
# saved
# Querying  10374 Sticker | Bomb Doge
# saved
# Querying  10375 Sticker | Bomb Squad (Foil)
# saved
# Querying  10376 Sticker | Bombsquad
# saved
# Querying  10377 Sticker | Bombsquad (Foil)
# saved
# Querying  10378 Sticker | Bonehead
# saved
# Querying  10379 Sticker | Bonehead (Holo)
# saved
# Querying  10380 Sticker | Boom
# saved
# Querying  10381 Sticker | Boom (Foil)
# saved
# Querying  10382 Sticker | Boom (Foil) | 2020 RMR
# saved
# Querying  10383 Sticker | Boom (Gold) | 2020 RMR
# saved
# Querying  10384 Sticker | Boom (Holo)
# saved
# Querying  10385 Sticker | Boom (Holo) | 2020 RMR
# saved
# Querying  10386 Sticker | Boom | 2020 RMR
# saved
# Querying  10387 Sticker | Boom(Foil)
# saved
# Querying  10388 Sticker | Boom(Holo)
# saved
# Querying  10389 Sticker | Boombl4 (Foil) | Berlin 2019
# saved
# Querying  10390 Sticker | Boombl4 (Foil) | Boston 2018
# saved
# Querying  10391 Sticker | Boombl4 (Foil) | Katowice 2019
# saved
# Querying  10392 Sticker | Boombl4 (Foil) | London 2018
# saved
# Querying  10393 Sticker | Boombl4 (Glitter) | Antwerp 2022
# saved
# Querying  10394 Sticker | Boombl4 (Glitter) | Copenhagen 2024
# saved
# Querying  10395 Sticker | Boombl4 (Gold) | Antwerp 2022
# saved
# Querying  10396 Sticker | Boombl4 (Gold) | Berlin 2019
# saved
# Querying  10397 Sticker | Boombl4 (Gold) | Boston 2018
# saved
# Querying  10398 Sticker | Boombl4 (Gold) | Copenhagen 2024
# saved
# Querying  10399 Sticker | Boombl4 (Gold) | Katowice 2019
# saved
# Querying  10400 Sticker | Boombl4 (Gold) | London 2018
# saved
# Querying  10401 Sticker | Boombl4 (Gold) | Stockholm 2021
# saved
# Querying  10402 Sticker | Boombl4 (Holo) | Antwerp 2022
# saved
# Querying  10403 Sticker | Boombl4 (Holo) | Copenhagen 2024
# saved
# Querying  10404 Sticker | Boombl4 (Holo) | Stockholm 2021
# saved
# Querying  10405 Sticker | Boombl4 | Antwerp 2022
# saved
# Querying  10406 Sticker | Boombl4 | Berlin 2019
# saved
# Querying  10407 Sticker | Boombl4 | Boston 2018
# saved
# Querying  10408 Sticker | Boombl4 | Copenhagen 2024
# saved
# Querying  10409 Sticker | Boombl4 | Katowice 2019
# saved
# Querying  10410 Sticker | Boombl4 | London 2018
# saved
# Querying  10411 Sticker | Boombl4 | Stockholm 2021
# saved
# Querying  10412 Sticker | Boost (Holo)
# saved
# Querying  10413 Sticker | Booth
# saved
# Querying  10414 Sticker | Boris
# saved
# Querying  10415 Sticker | Boris (Holo)
# saved
# Querying  10416 Sticker | Bosh (Holo)
# saved
# Querying  10417 Sticker | Bossy Burger
# saved
# Querying  10418 Sticker | Bravado Gaming | DreamHack 2014
# saved
# Querying  10419 Sticker | Brehze (Foil) | Berlin 2019
# saved
# Querying  10420 Sticker | Brehze (Foil) | Katowice 2019
# saved
# Querying  10421 Sticker | Brehze (Glitter) | Rio 2022
# saved
# Querying  10422 Sticker | Brehze (Gold) | Berlin 2019
# saved
# Querying  10423 Sticker | Brehze (Gold) | Katowice 2019
# saved
# Querying  10424 Sticker | Brehze (Gold) | Rio 2022
# saved
# Querying  10425 Sticker | Brehze (Holo) | Rio 2022
# saved
# Querying  10426 Sticker | Brehze | Berlin 2019
# saved
# Querying  10427 Sticker | Brehze | Katowice 2019
# saved
# Querying  10428 Sticker | Brehze | Rio 2022
# saved
# Querying  10429 Sticker | Broken Fang
# saved
# Querying  10430 Sticker | Broken Fang (Holo)
# saved
# Querying  10431 Sticker | Brollan (Foil) | Katowice 2019
# saved
# Querying  10432 Sticker | Brollan (Glitter) | Antwerp 2022
# saved
# Querying  10433 Sticker | Brollan (Glitter) | Copenhagen 2024
# saved
# Querying  10434 Sticker | Brollan (Glitter) | Paris 2023
# saved
# Querying  10435 Sticker | Brollan (Glitter) | Rio 2022
# saved
# Querying  10436 Sticker | Brollan (Gold) | Antwerp 2022
# saved
# Querying  10437 Sticker | Brollan (Gold) | Copenhagen 2024
# saved
# Querying  10438 Sticker | Brollan (Gold) | Katowice 2019
# saved
# Querying  10439 Sticker | Brollan (Gold) | Paris 2023
# saved
# Querying  10440 Sticker | Brollan (Gold) | Rio 2022
# saved
# Querying  10441 Sticker | Brollan (Holo) | Antwerp 2022
# saved
# Querying  10442 Sticker | Brollan (Holo) | Copenhagen 2024
# saved
# Querying  10443 Sticker | Brollan (Holo) | Paris 2023
# saved
# Querying  10444 Sticker | Brollan (Holo) | Rio 2022
# saved
# Querying  10445 Sticker | Brollan | Antwerp 2022
# saved
# Querying  10446 Sticker | Brollan | Copenhagen 2024
# saved
# Querying  10447 Sticker | Brollan | Katowice 2019
# saved
# Querying  10448 Sticker | Brollan | Paris 2023
# saved
# Querying  10449 Sticker | Brollan | Rio 2022
# saved
# Querying  10450 Sticker | Bubble Gum Skill Surf (Holo)
# saved
# Querying  10451 Sticker | BukAWP
# saved
# Querying  10452 Sticker | Bullet Hell (Foil)
# saved
# Querying  10453 Sticker | Bullet Rain
# saved
# Querying  10454 Sticker | Bullet Rain (Foil)
# saved
# Querying  10455 Sticker | Bum A Smoke
# saved
# Querying  10456 Sticker | Burn Them All
# saved
# Querying  10457 Sticker | C-S On The Go
# saved
# Querying  10458 Sticker | COLDYY1 (Foil) | Katowice 2019
# saved
# Querying  10459 Sticker | COLDYY1 (Foil) | London 2018
# saved
# Querying  10460 Sticker | COLDYY1 (Gold) | Katowice 2019
# saved
# Querying  10461 Sticker | COLDYY1 (Gold) | London 2018
# saved
# Querying  10462 Sticker | COLDYY1 | Katowice 2019
# saved
# Querying  10463 Sticker | COLDYY1 | London 2018
# saved
# Querying  10464 Sticker | CR4ZY (Foil) | Berlin 2019
# saved
# Querying  10465 Sticker | CR4ZY (Holo) | Berlin 2019
# saved
# Querying  10466 Sticker | CR4ZY | Berlin 2019
# saved
# Querying  10467 Sticker | CRUC1AL (Glitter) | Paris 2023
# saved
# Querying  10468 Sticker | CRUC1AL (Gold) | Paris 2023
# saved
# Querying  10469 Sticker | CRUC1AL (Holo) | Paris 2023
# saved
# Querying  10470 Sticker | CRUC1AL | Paris 2023
# saved
# Querying  10471 Sticker | CS On The Mind
# saved
# Querying  10472 Sticker | CS20 Classic (Holo)
# saved
# Querying  10473 Sticker | CT in Banana
# saved
# Querying  10474 Sticker | CacaNito (Glitter) | Copenhagen 2024
# saved
# Querying  10475 Sticker | CacaNito (Gold) | Copenhagen 2024
# saved
# Querying  10476 Sticker | CacaNito (Holo) | Copenhagen 2024
# saved
# Querying  10477 Sticker | CacaNito | Copenhagen 2024
# saved
# Querying  10478 Sticker | Call Your Flashes
# saved
# Querying  10479 Sticker | Calyx (Foil) | Boston 2018
# saved
# Querying  10480 Sticker | Calyx (Foil) | London 2018
# saved
# Querying  10481 Sticker | Calyx (Glitter) | Antwerp 2022
# saved
# Querying  10482 Sticker | Calyx (Glitter) | Copenhagen 2024
# saved
# Querying  10483 Sticker | Calyx (Gold) | Antwerp 2022
# saved
# Querying  10484 Sticker | Calyx (Gold) | Boston 2018
# saved
# Querying  10485 Sticker | Calyx (Gold) | Copenhagen 2024
# saved
# Querying  10486 Sticker | Calyx (Gold) | London 2018
# saved
# Querying  10487 Sticker | Calyx (Holo) | Antwerp 2022
# saved
# Querying  10488 Sticker | Calyx (Holo) | Copenhagen 2024
# saved
# Querying  10489 Sticker | Calyx | Antwerp 2022
# saved
# Querying  10490 Sticker | Calyx | Boston 2018
# saved
# Querying  10491 Sticker | Calyx | Copenhagen 2024
# saved
# Querying  10492 Sticker | Calyx | London 2018
# saved
# Querying  10493 Sticker | Camper
# saved
# Querying  10494 Sticker | Camper (Foil)
# saved
# Querying  10495 Sticker | Candy Buttery (Holo)
# saved
# Querying  10496 Sticker | Cat Call
# saved
# Querying  10497 Sticker | Cbbl (Holo)
# saved
# Querying  10498 Sticker | CeRq (Foil) | Berlin 2019
# saved
# Querying  10499 Sticker | CeRq (Foil) | Katowice 2019
# saved
# Querying  10500 Sticker | CeRq (Glitter) | Rio 2022
# saved
# Querying  10501 Sticker | CeRq (Gold) | Berlin 2019
# saved
# Querying  10502 Sticker | CeRq (Gold) | Katowice 2019
# saved
# Querying  10503 Sticker | CeRq (Gold) | Rio 2022
# saved
# Querying  10504 Sticker | CeRq (Holo) | Rio 2022
# saved
# Querying  10505 Sticker | CeRq | Berlin 2019
# saved
# Querying  10506 Sticker | CeRq | Katowice 2019
# saved
# Querying  10507 Sticker | CeRq | Rio 2022
# saved
# Querying  10508 Sticker | Cedar Creek (Holo)
# saved
# Querying  10509 Sticker | Cerberus
# saved
# Querying  10510 Sticker | Chabo
# saved
# Querying  10511 Sticker | Chaos Marine (Foil)
# saved
# Querying  10512 Sticker | Cheongsam
# saved
# Querying  10513 Sticker | Cheongsam (Holo)
# saved
# Querying  10514 Sticker | Chi Bomb
# saved
# Querying  10515 Sticker | Chicken Lover
# saved
# Querying  10516 Sticker | Chicken Strike
# saved
# Querying  10517 Sticker | Chicken Whisperer
# saved
# Querying  10518 Sticker | Chicken of the Sky
# saved
# Querying  10519 Sticker | Chief
# saved
# Querying  10520 Sticker | Chief (Foil)
# saved
# Querying  10521 Sticker | Chief (Holo)
# saved
# Querying  10522 Sticker | Choose Wisely
# saved
# Querying  10523 Sticker | Clan-Mystik (Holo) | Katowice 2014
# saved
# Querying  10524 Sticker | Clan-Mystik | Katowice 2014
# saved
# Querying  10525 Sticker | Clicking Heads
# saved
# Querying  10526 Sticker | Cloud9 (Foil) | Boston 2018
# saved
# Querying  10527 Sticker | Cloud9 (Foil) | Cluj-Napoca 2015
# saved
# Querying  10528 Sticker | Cloud9 (Foil) | DreamHack 2014
# saved
# Querying  10529 Sticker | Cloud9 (Foil) | Katowice 2019
# saved
# Querying  10530 Sticker | Cloud9 (Foil) | Krakow 2017
# saved
# Querying  10531 Sticker | Cloud9 (Foil) | London 2018
# saved
# Querying  10532 Sticker | Cloud9 (Foil) | MLG Columbus 2016
# saved
# Querying  10533 Sticker | Cloud9 (Glitter) | Antwerp 2022
# saved
# Querying  10534 Sticker | Cloud9 (Glitter) | Copenhagen 2024
# saved
# Querying  10535 Sticker | Cloud9 (Glitter) | Rio 2022
# saved
# Querying  10536 Sticker | Cloud9 (Gold) | Antwerp 2022
# saved
# Querying  10537 Sticker | Cloud9 (Gold) | Copenhagen 2024
# saved
# Querying  10538 Sticker | Cloud9 (Gold) | Rio 2022
# saved
# Querying  10539 Sticker | Cloud9 (Holo) | Antwerp 2022
# saved
# Querying  10540 Sticker | Cloud9 (Holo) | Boston 2018
# saved
# Querying  10541 Sticker | Cloud9 (Holo) | Cologne 2014
# saved
# Querying  10542 Sticker | Cloud9 (Holo) | Copenhagen 2024
# saved
# Querying  10543 Sticker | Cloud9 (Holo) | DreamHack 2014
# saved
# Querying  10544 Sticker | Cloud9 (Holo) | Katowice 2019
# saved
# Querying  10545 Sticker | Cloud9 (Holo) | Krakow 2017
# saved
# Querying  10546 Sticker | Cloud9 (Holo) | London 2018
# saved
# Querying  10547 Sticker | Cloud9 (Holo) | MLG Columbus 2016
# saved
# Querying  10548 Sticker | Cloud9 (Holo) | Rio 2022
# saved
# Querying  10549 Sticker | Cloud9 G2A (Foil) | Cologne 2015
# saved
# Querying  10550 Sticker | Cloud9 G2A (Foil) | Katowice 2015
# saved
# Querying  10551 Sticker | Cloud9 G2A (Holo) | Katowice 2015
# saved
# Querying  10552 Sticker | Cloud9 G2A | Cologne 2015
# saved
# Querying  10553 Sticker | Cloud9 G2A | Katowice 2015
# saved
# Querying  10554 Sticker | Cloud9 | Antwerp 2022
# saved
# Querying  10555 Sticker | Cloud9 | Boston 2018
# saved
# Querying  10556 Sticker | Cloud9 | Cluj-Napoca 2015
# saved
# Querying  10557 Sticker | Cloud9 | Cologne 2014
# saved
# Querying  10558 Sticker | Cloud9 | Copenhagen 2024
# saved
# Querying  10559 Sticker | Cloud9 | DreamHack 2014
# saved
# Querying  10560 Sticker | Cloud9 | Katowice 2019
# saved
# Querying  10561 Sticker | Cloud9 | Krakow 2017
# saved
# Querying  10562 Sticker | Cloud9 | London 2018
# saved
# Querying  10563 Sticker | Cloud9 | MLG Columbus 2016
# saved
# Querying  10564 Sticker | Cloud9 | Rio 2022
# saved
# Querying  10565 Sticker | Cluck
# saved
# Querying  10566 Sticker | Cluck (Holo)
# saved
# Querying  10567 Sticker | Clutch Or Kick
# saved
# Querying  10568 Sticker | Clutchman (Holo)
# saved
# Querying  10569 Sticker | Co Co Co
# saved
# Querying  10570 Sticker | Coiled Strike
# saved
# Querying  10571 Sticker | Coiled Strike (Holo)
# saved
# Querying  10572 Sticker | Combine Helmet
# saved
# Querying  10573 Sticker | Combine Helmet (Holo)
# saved
# Querying  10574 Sticker | Come Here Boy
# saved
# Querying  10575 Sticker | Complexity Gaming (Glitter) | Antwerp 2022
# saved
# Querying  10576 Sticker | Complexity Gaming (Glitter) | Copenhagen 2024
# saved
# Querying  10577 Sticker | Complexity Gaming (Glitter) | Paris 2023
# saved
# Querying  10578 Sticker | Complexity Gaming (Gold) | Antwerp 2022
# saved
# Querying  10579 Sticker | Complexity Gaming (Gold) | Copenhagen 2024
# saved
# Querying  10580 Sticker | Complexity Gaming (Gold) | Paris 2023
# saved
# Querying  10581 Sticker | Complexity Gaming (Holo) | Antwerp 2022
# saved
# Querying  10582 Sticker | Complexity Gaming (Holo) | Copenhagen 2024
# saved
# Querying  10583 Sticker | Complexity Gaming (Holo) | Paris 2023
# saved
# Querying  10584 Sticker | Complexity Gaming | Antwerp 2022
# saved
# Querying  10585 Sticker | Complexity Gaming | Copenhagen 2024
# saved
# Querying  10586 Sticker | Complexity Gaming | Paris 2023
# saved
# Querying  10587 Sticker | Conspiracy Club (Holo)
# saved
# Querying  10588 Sticker | Copenhagen Flames (Foil) | Stockholm 2021
# saved
# Querying  10589 Sticker | Copenhagen Flames (Glitter) | Antwerp 2022
# saved
# Querying  10590 Sticker | Copenhagen Flames (Gold) | Antwerp 2022
# saved
# Querying  10591 Sticker | Copenhagen Flames (Gold) | Stockholm 2021
# saved
# Querying  10592 Sticker | Copenhagen Flames (Holo) | Antwerp 2022
# saved
# Querying  10593 Sticker | Copenhagen Flames (Holo) | Stockholm 2021
# saved
# Querying  10594 Sticker | Copenhagen Flames | Antwerp 2022
# saved
# Querying  10595 Sticker | Copenhagen Flames | Stockholm 2021
# saved
# Querying  10596 Sticker | Copenhagen Wolves (Holo) | Cologne 2014
# saved
# Querying  10597 Sticker | Copenhagen Wolves | Cologne 2014
# saved
# Querying  10598 Sticker | Copenhagen Wolves | DreamHack 2014
# saved
# Querying  10599 Sticker | Coral Skill Surf (Holo)
# saved
# Querying  10600 Sticker | Cotton Candy Flow (Holo)
# saved
# Querying  10601 Sticker | Countdown
# saved
# Querying  10602 Sticker | Countdown (Foil)
# saved
# Querying  10603 Sticker | Countdown (Holo)
# saved
# Querying  10604 Sticker | Countdown(Foil)
# saved
# Querying  10605 Sticker | Counter Logic Gaming (Foil) | Cluj-Napoca 2015
# saved
# Querying  10606 Sticker | Counter Logic Gaming (Foil) | Cologne 2015
# saved
# Querying  10607 Sticker | Counter Logic Gaming (Foil) | Cologne 2016
# saved
# Querying  10608 Sticker | Counter Logic Gaming (Foil) | Katowice 2015
# saved
# Querying  10609 Sticker | Counter Logic Gaming (Foil) | MLG Columbus 2016
# saved
# Querying  10610 Sticker | Counter Logic Gaming (Holo) | Cologne 2016
# saved
# Querying  10611 Sticker | Counter Logic Gaming (Holo) | Katowice 2015
# saved
# Querying  10612 Sticker | Counter Logic Gaming (Holo) | MLG Columbus 2016
# saved
# Querying  10613 Sticker | Counter Logic Gaming | Cluj-Napoca 2015
# saved
# Querying  10614 Sticker | Counter Logic Gaming | Cologne 2015
# saved
# Querying  10615 Sticker | Counter Logic Gaming | Cologne 2016
# saved
# Querying  10616 Sticker | Counter Logic Gaming | Katowice 2015
# saved
# Querying  10617 Sticker | Counter Logic Gaming | MLG Columbus 2016
# saved
# Querying  10618 Sticker | Counter-Tech
# saved
# Querying  10619 Sticker | Coutdown (Holo)
# saved
# Querying  10620 Sticker | Coutdown(Holo)
# saved
# Querying  10621 Sticker | Crimson Web Poison Frog (Foil)
# saved
# Querying  10622 Sticker | Crown (Foil)
# saved
# Querying  10623 Sticker | Cursed Penmanship
# saved
# Querying  10624 Sticker | Cyber Chicken (Holo)
# saved
# Querying  10625 Sticker | Cyber Romanov (Holo)
# saved
# Querying  10626 Sticker | Cypher (Glitter) | Paris 2023
# saved
# Querying  10627 Sticker | Cypher (Gold) | Paris 2023
# saved
# Querying  10628 Sticker | Cypher (Holo) | Paris 2023
# saved
# Querying  10629 Sticker | Cypher | Paris 2023
# saved
# Querying  10630 Sticker | DAVEY (Foil) | MLG Columbus 2016
# saved
# Querying  10631 Sticker | DAVEY | MLG Columbus 2016
# saved
# Querying  10632 Sticker | DD (Foil) | Boston 2018
# saved
# Querying  10633 Sticker | DD (Foil) | London 2018
# saved
# Querying  10634 Sticker | DD (Gold) | Boston 2018
# saved
# Querying  10635 Sticker | DD (Gold) | London 2018
# saved
# Querying  10636 Sticker | DD | Boston 2018
# saved
# Querying  10637 Sticker | DD | London 2018
# saved
# Querying  10638 Sticker | DEVIL (Foil) | Cologne 2016
# saved
# Querying  10639 Sticker | DEVIL (Foil) | MLG Columbus 2016
# saved
# Querying  10640 Sticker | DEVIL | Cologne 2016
# saved
# Querying  10641 Sticker | DEVIL | MLG Columbus 2016
# saved
# Querying  10642 Sticker | DJ Safecracker (Lenticular)
# saved
# Querying  10643 Sticker | Dark Water Surf Ava (Foil)
# saved
# Querying  10644 Sticker | DavCost (Foil) | Cluj-Napoca 2015
# saved
# Querying  10645 Sticker | DavCost (Foil) | Cologne 2015
# saved
# Querying  10646 Sticker | DavCost (Foil) | Katowice 2019
# saved
# Querying  10647 Sticker | DavCost (Foil) | London 2018
# saved
# Querying  10648 Sticker | DavCost (Gold) | Katowice 2019
# saved
# Querying  10649 Sticker | DavCost (Gold) | London 2018
# saved
# Querying  10650 Sticker | DavCost | Cluj-Napoca 2015
# saved
# Querying  10651 Sticker | DavCost | Cologne 2015
# saved
# Querying  10652 Sticker | DavCost | Katowice 2019
# saved
# Querying  10653 Sticker | DavCost | London 2018
# saved
# Querying  10654 Sticker | DeStiNy (Foil) | Berlin 2019
# saved
# Querying  10655 Sticker | DeStiNy (Gold) | Berlin 2019
# saved
# Querying  10656 Sticker | DeStiNy | Berlin 2019
# saved
# Querying  10657 Sticker | Dead Eye
# saved
# Querying  10658 Sticker | Dead Eye (Holo)
# saved
# Querying  10659 Sticker | DeadFox (Foil) | Atlanta 2017
# saved
# Querying  10660 Sticker | DeadFox (Foil) | Berlin 2019
# saved
# Querying  10661 Sticker | DeadFox (Foil) | Katowice 2019
# saved
# Querying  10662 Sticker | DeadFox (Foil) | London 2018
# saved
# Querying  10663 Sticker | DeadFox (Gold) | Berlin 2019
# saved
# Querying  10664 Sticker | DeadFox (Gold) | Katowice 2019
# saved
# Querying  10665 Sticker | DeadFox (Gold) | London 2018
# saved
# Querying  10666 Sticker | DeadFox | Atlanta 2017
# saved
# Querying  10667 Sticker | DeadFox | Berlin 2019
# saved
# Querying  10668 Sticker | DeadFox | Katowice 2019
# saved
# Querying  10669 Sticker | DeadFox | London 2018
# saved
# Querying  10670 Sticker | Death Comes
# saved
# Querying  10671 Sticker | Defuse It (Holo)
# saved
# Querying  10672 Sticker | Delicious Tears
# saved
# Querying  10673 Sticker | DemQQ (Glitter) | Paris 2023
# saved
# Querying  10674 Sticker | DemQQ (Gold) | Paris 2023
# saved
# Querying  10675 Sticker | DemQQ (Holo) | Paris 2023
# saved
# Querying  10676 Sticker | DemQQ | Paris 2023
# saved
# Querying  10677 Sticker | Dessert Eagle
# saved
# Querying  10678 Sticker | Devouring Flame
# saved
# Querying  10679 Sticker | Devouring Flame (Holo)
# saved
# Querying  10680 Sticker | DickStacy (Foil) | Berlin 2019
# saved
# Querying  10681 Sticker | DickStacy (Foil) | Katowice 2019
# saved
# Querying  10682 Sticker | DickStacy (Gold) | Berlin 2019
# saved
# Querying  10683 Sticker | DickStacy (Gold) | Katowice 2019
# saved
# Querying  10684 Sticker | DickStacy | Berlin 2019
# saved
# Querying  10685 Sticker | DickStacy | Katowice 2019
# saved
# Querying  10686 Sticker | Dima (Foil) | Katowice 2019
# saved
# Querying  10687 Sticker | Dima (Foil) | London 2018
# saved
# Querying  10688 Sticker | Dima (Gold) | Katowice 2019
# saved
# Querying  10689 Sticker | Dima (Gold) | London 2018
# saved
# Querying  10690 Sticker | Dima | Katowice 2019
# saved
# Querying  10691 Sticker | Dima | London 2018
# saved
# Querying  10692 Sticker | Dinked
# saved
# Querying  10693 Sticker | Dirty Money
# saved
# Querying  10694 Sticker | Distinguished Master Guardian
# saved
# Querying  10695 Sticker | Distinguished Master Guardian (Holo)
# saved
# Querying  10696 Sticker | Don't Worry
# saved
# Querying  10697 Sticker | Don't Worry (Foil)
# saved
# Querying  10698 Sticker | Don't Worry (Holo)
# saved
# Querying  10699 Sticker | Don't Worry(Foil)
# saved
# Querying  10700 Sticker | Don't Worry(Holo)
# saved
# Querying  10701 Sticker | Don't Worry, I'm Pro
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       4 item_id = items[i]
#       5 print("Querying ",i, item_id)
# ----> 6 res = get(url=f"https://steamcommunity.com/market/pricehistory/?appid=730&market_hash_name={urlquote(item_id)}", cookies={"steamLoginSecure": login_token})
#       8 if res.status_code != 200:
#       9     print(f"Bad Response Code: {res.status_code} on item: {item_id}")
#
# File ~\miniconda3\envs\MarketReview\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\miniconda3\envs\MarketReview\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\miniconda3\envs\MarketReview\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\miniconda3\envs\MarketReview\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\miniconda3\envs\MarketReview\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~\miniconda3\envs\MarketReview\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\miniconda3\envs\MarketReview\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\miniconda3\envs\MarketReview\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~\miniconda3\envs\MarketReview\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~\miniconda3\envs\MarketReview\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\miniconda3\envs\MarketReview\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\miniconda3\envs\MarketReview\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\miniconda3\envs\MarketReview\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\miniconda3\envs\MarketReview\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
